# %% [markdown]
# # CartPole Environment
#
# The CartPole environment is a classic OpenAI gym environment that can be used to test the efficacy of an RL agent in a MDP environment with a continuous observation space (state space).
#
# In brief, the environment consists of a pole attached by an un-acuated joint to a cart, which moves along a frictionless track. The system is controlled by applying a force of +1 or -1 to the cart, with the former resulting in the cart moving right, and the latter resulting in the cart moving left. The pendulum starts upright on the cart, and the goal of the RL agent is to prevent it from falling over by playing a balancing act with the left and right forces it exerts on the cart.

# %% [markdown]
# ## CartPole Environment Details
#
# The details about the CartPole environment's observation space, action space, and reward signals are provided in the OpenAI gym documentation (https://github.com/openai/gym/blob/master/gym/envs/classic_control/cartpole.py) as follows:
#
#
# ### Observation Space
#
# The observation space consists of 4 variables, each being constrained by their own set of (min, max) values as provided in the table below:
#
# | Num | Observation   | Min | Max|
# |------|------|------|------|
# |   0  |    Cart Position |   -4.8   |  4.8   |
# |   1  |   Cart Velocity  |   -Infinity   |  Infinity   |
# |   2  |   Pole Angle  |   -24 degrees   |   24 degrees  |
# |   3  |   Pole Velocity at Tip  |    -Infinity   |  Infinity     |
#
# As can be seen from the table, the observation space variables consists of continuous values, i.e. it would be virtually impossible to create a lookup table of state-value or action-value pairs over this space. As such, a function approximator, such as a neural network, will have to be used by the RL agent to approximate value functions so that the optimal policy can be found.
#
# ### Action Space
#
# The action space consists of 2 discrete variables. The integer symbols and their corresponding actions are provided as follows:
#
# - 0: 	Push cart to the left
# - 1:	Push cart to the right
#
# Note: The amount the velocity that is reduced or increased is not fixed; it depends on the angle the pole is pointing. This is because the center of gravity of the pole increases the amount of energy needed to move the cart underneath it
#
# ### Reward Signals
#
# There is a reward of +1 for every step taken, including the termination step. This means that the greater the amount of time-steps that the pole is kept upright by the agent, the greater the reward received.
#
# ### Starting State
# All observations are assigned a uniform random value in [-0.05..0.05]
#
# ### Episode Termination
#
# The episode terminates when:
#
# - Pole Angle is more than 12 degrees, i.e. pole is about to fall. (Failure state)
# - Cart Position is more than 2.4, i.e. center of the cart reaches the edge of the display screen. (Failure state)
# - Episode length is greater than 200, i.e. pole has been kept upright for longer than 200 time-steps. (Success state)
#
# ### Solved Requirements
#
# This environment is considered solved when the average reward is greater than or equal to 195.0 over 100 consecutive trials. That is, the pole has been kept upright for 195 timesteps or longer for 100episodes in a row.
#
# ### Source
#
# This environment corresponds to the version of the cart-pole problem described by Barto, Sutton, and Anderson [Example 3.4, page 86].

# %% [markdown]
# # Exploring the Environment
#
# For each step our RL agent takes in the CartPole environment, we receive `observation`, `reward`, `done`, and `info` in return.
#
# - `observation` returns the cart position, cart velocity, pole angle, and pole velocity at the tip.
#
# - `reward` returns the amount of reward achieved by the previous action, i.e. +1 if the pole remains upright. There is no negative reward since the episode will terminate if the pole falls.
#
# - `done` indicates that the episode has been terminated because the pole angle is more than 12 degrees, the cart position is more than 2.4, or the number of time steps is greater than 200.
#
# - `info` contains diagnostic information to help in debugging.
#
# In a typical setup, we start with an initial set of observations from the environment - this denotes the starting point of our agent. Using information from the observations, the agent takes an initial step by performing an action (denoted as `env.step(action)` , where action is sampled from the `env.action_space`) and enters the "agent-environment" loop. That is, the action leads to a new observation and reward, which the agent then uses to choose its next action (assuming a non-random policy).
#
# <img src="http://gym.openai.com/assets/docs/aeloop-138c89d44114492fd02822303e6b4b07213010bb14ca5856d2d49d6b62d88e53.svg"/>

# %%
import gym
import math
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# create cartpole environment
env = gym.make('CartPole-v1')

# number of actions
print(f"Number of actions: {env.action_space}")

# 10 random samples from action space
action_sample = [env.action_space.sample() for i in range(10)]
print(f"10 random samples from action space: {action_sample}")

print()
# number of states
print(f"Number of states: {env.observation_space}")
print(f"Max: {env.observation_space.high.round(2)}")
print(f"Min: {env.observation_space.low.round(2)}")

# 10 random samples from state space
obs_sample = env.observation_space.sample()
print(f"One random sample from observation space:\n {obs_sample}")
# Out:
# Number of actions: Discrete(2)
# 10 random samples from action space: [1, 1, 1, 1, 0, 1, 1, 1, 0, 0]
#
# Number of states: Box(4,)
# Max: [4.8   inf 0.42  inf]
# Min: [-4.8   -inf -0.42  -inf]
# One random sample from observation space:
#  [ 4.2190156e+00  2.4108467e+38 -8.4720016e-02  9.3216798e+37]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: overflow encountered in multiply
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:24: RuntimeWarning: overflow encountered in multiply

# %%
time_steps = []

# run sim
for episode in range(1):
    
    print(f"Starting episode {episode}:")
    # get initial observation
    observation = env.reset()
    
    # run each episode for 200 time steps
    for t in range(200):
        
        # render the environment
        env.render()
        
        # cart pos, cart vel, pole angle, pole vel
        print(observation)
        
        # randomly choose an action from the action space
        action = env.action_space.sample()
        
        # take a step in the environment
        observation, reward, done, info = env.step(action)
        
        if done: break
            
    print(f"Episode finished after {t+1} timesteps")
    time_steps.append(t+1)
            
env.close()

print(f"Average timesteps/reward: {np.mean(time_steps)}")
# Out:
# Starting episode 0:
# [ 0.01060798 -0.02822754  0.01155789 -0.01333882]
# [ 0.01004343 -0.22351332  0.01129111  0.28296823]
# [ 0.00557317 -0.02855422  0.01695047 -0.00613226]
# [ 0.00500208 -0.22391511  0.01682783  0.29185019]
# [ 0.00052378 -0.02903709  0.02266483  0.00452169]
# [-5.69621361e-05 -2.24476634e-01  2.27552661e-02  3.04268597e-01]
# [-0.00454649 -0.02968624  0.02884064  0.01884812]
# [-0.00514022 -0.22520967  0.0292176   0.32048927]
# [-0.00964441 -0.03051573  0.03562739  0.03716176]
# [-0.01025473  0.16407768  0.03637062 -0.2440709 ]
# [-0.00697317  0.35866177  0.0314892  -0.5250634 ]
# [ 2.00061524e-04  5.53326772e-01  2.09879351e-02 -8.07659843e-01]
# [ 0.0112666   0.35792356  0.00483474 -0.50844958]
# [ 0.01842507  0.16273383 -0.00533425 -0.214247  ]
# [ 0.02167974 -0.03231145 -0.00961919  0.0767485 ]
# [ 0.02103352  0.16294706 -0.00808422 -0.21895372]
# [ 0.02429246 -0.0320584  -0.0124633   0.07116818]
# [ 0.02365129 -0.22699947 -0.01103993  0.35989296]
# [ 0.0191113  -0.03172234 -0.00384208  0.06374944]
# [ 0.01847685 -0.226789   -0.00256709  0.3552177 ]
# [ 0.01394107 -0.03163064  0.00453727  0.0617264 ]
# [ 0.01330846  0.16342596  0.0057718  -0.22952154]
# [ 0.01657698 -0.03177799  0.00118137  0.06497641]
# [ 0.01594142 -0.22691686  0.00248089  0.35803183]
# [ 0.01140308 -0.42207399  0.00964153  0.65149601]
# [ 0.0029616  -0.22708764  0.02267145  0.36186464]
# [-0.00158015 -0.03229515  0.02990874  0.07641583]
# [-0.00222605 -0.22783281  0.03143706  0.37838301]
# [-0.00678271 -0.0331711   0.03900472  0.09577569]
# [-0.00744613 -0.22882975  0.04092023  0.40050492]
# [-0.01202273 -0.42450754  0.04893033  0.70580309]
# [-0.02051288 -0.62027206  0.06304639  1.0134782 ]
# [-0.03291832 -0.42604517  0.08331596  0.74124006]
# [-0.04143922 -0.62221246  0.09814076  1.05893686]
# [-0.05388347 -0.8184878   0.1193195   1.38074026]
# [-0.07025323 -1.01487975  0.1469343   1.70823038]
# [-0.09055082 -1.2113538   0.18109891  2.04280923]
# Episode finished after 37 timesteps
# Average timesteps/reward: 37.0

# %% [markdown]
# # Q-Learning
#
# Q-learning is a "tabular" method for approximating the optimal value function. That is, it relies on building a lookup table of action-value pairs, that our agent can then search over using a given policy, such as an $\epsilon$-greedy policy.
#
# Since the observation space in the CartPole environment consists of continuous values, in order to apply Q-learning to learn how to balance the pole, we first need to discretize the environment.

# %% [markdown]
# ## Agent Architecture

# %%
import random
import copy
from collections import defaultdict
from collections import namedtuple

class Q():
    
    # Reference: https://github.com/icoxfog417/cartpole-q-learning

    def __init__(self, n_actions, observation_space, bin_size, low_bound=None, high_bound=None, initial_mean=0.0, initial_std=0.0):
        self.n_actions = n_actions
        self._observation_dimension = 1
        for d in observation_space.shape:
            self._observation_dimension *= d

        self._bin_sizes = bin_size if isinstance(bin_size, list) else [bin_size] * self._observation_dimension
        self._dimension_bins = []
        for i, low, high in self._low_high_iter(observation_space, low_bound, high_bound):
            b_size = self._bin_sizes[i]
            bins = self._make_bins(low, high, b_size)
            self._dimension_bins.append(bins)

        # if we encounter the new observation, we initialize action evaluations
        self.table = defaultdict(lambda: initial_std * np.random.randn(self.n_actions) + initial_mean)
    
    @classmethod
    def _make_bins(cls, low, high, bin_size):
        bins = np.arange(low, high, (float(high) - float(low)) / (bin_size - 2))  # exclude both ends
        if min(bins) < 0 and 0 not in bins:
            bins = np.sort(np.append(bins, [0]))  # 0 centric bins
        return bins
    
    @classmethod
    def _low_high_iter(cls, observation_space, low_bound, high_bound):
        lows = observation_space.low
        highs = observation_space.high
        for i in range(len(lows)):
            low = lows[i]
            if low_bound is not None:
                _low_bound = low_bound if not isinstance(low_bound, list) else low_bound[i]
                low = low if _low_bound is None else max(low, _low_bound)
            
            high = highs[i]
            if high_bound is not None:
                _high_bound = high_bound if not isinstance(high_bound, list) else high_bound[i]
                high = high if _high_bound is None else min(high, _high_bound)
            
            yield i, low, high

    def observation_to_state(self, observation):
        state = 0
        # caution: bin_size over 10 will not work accurately
        unit = max(self._bin_sizes)
        for d, o in enumerate(observation.flatten()):
            state = state + np.digitize(o, self._dimension_bins[d]) * pow(unit, d)  # bin_size numeral system
        return state
    
    def values(self, observation):
        state = self.observation_to_state(observation)
        return self.table[state]


class q_learning_Agent():
    '''
    Q-learning Agent with epsilon-greedy policy.
    '''

    def __init__(self, q, epsilon):
        
        self.q = q
        self.epsilon = epsilon
    
    def act(self, observation):
        
        action = -1
        
        if np.random.random() < self.epsilon:
            # randomly select action from q-table
            action = np.random.choice(self.q.n_actions)
        else:
            # select max state-action pair from q-table for a given observation
            action = np.argmax(self.q.values(observation))
        
        return action


class Trainer:
    
    '''
    Parent Trainer class.
    Update method is defaulted to suit Q-learning agent, but 
    can be overwritten to suit different RL agent, e.g. DQN.
    '''

    def __init__(self, agent, gamma, learning_rate, epsilon, epsilon_decay, max_step):
        
        # RL agent
        self.agent = agent
        
        # params
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.agent.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.max_step = max_step
        
        # stats
        self.steps = [] # running count of time-steps
        
    
    def update(self, obs, action, reward, next_obs, done):
        '''
        Update step for Q-learning agent.
        The observation has to be discretized to insert into the lookup table.
        '''
        # convert obs to discrete state
        state = self.agent.q.observation_to_state(obs)
        # get value of next observation
        future_val = 0 if done else np.max(self.agent.q.values(next_obs))
        # get value of current observation
        current_val = self.agent.q.table[state][action]
        # get difference between future and current value (temporal difference)
        delta = future_val - current_val
        # update q-table
        self.agent.q.table[state][action] += self.learning_rate * (reward + self.gamma * delta)
    

    def train(self, env, episode_count, render=False):
        
        for i in range(episode_count):
            
            obs = env.reset() # get initial obs
            step = 0 # reset time step
            done = False
            
            while not done:
                
                if render: env.render()

                # select action based on agent's policy
                action = self.agent.act(obs)
                # take a step in the env based on selected action
                next_obs, reward, done, _ = env.step(action)

                # use Trainer's custom update method to perform update
                self.update(obs, action, reward, next_obs, done)

                # update agent's state
                obs = next_obs
                # increment timestep
                step += 1
                # terminate if exceed 250 steps
                if step > self.max_step: done = True

            # record number of time-steps for this episode
            self.steps.append(step)
            
            # decay the epsilon for next episode
            self.agent.epsilon = max(EXPLORATION_MIN, self.agent.epsilon * self.epsilon_decay)
            
            print(f'Ep: {i}| Reward: {round(step, 2)} | Epsilon: {round(self.agent.epsilon,2)}')
                
        if render: env.close()

# %% [markdown]
# ## Initialize Fixed Parameters

# %%
# Initialize params
ENV_NAME = "CartPole-v0" # gym environment
MAX_STEP = 250 # max episode length before terminating
GAMMA = 0.95 # discount rate - close to 1, far-sighted
LEARNING_RATE = 0.001 # small learning rate

EXPLORATION_MAX = 1.0 # epsilon upper bound
EXPLORATION_MIN = 0.01 # epsilon lower bound
EXPLORATION_DECAY = 0.995 # epsilon decay rate

# for DQN only
MEMORY_SIZE = 1000000 # replay memory
BATCH_SIZE = 20 # train in batches

# %% [markdown]
# ## Training the Agent

# %%
# create enviornment
env = gym.make(ENV_NAME) 

# create Q-table
q = Q(
    env.action_space.n, 
    env.observation_space, 
    bin_size=[10,10,10,10],
    low_bound=[None, -0.5, None, -math.radians(50)], 
    high_bound=[None, 0.5, None, math.radians(50)]
    )

#initialize Q-Learning trainer
q_learning_trainer = Trainer(
                        agent = q_learning_Agent(q, EXPLORATION_MAX), 
                        gamma = GAMMA,
                        learning_rate = LEARNING_RATE, 
                        epsilon = EXPLORATION_MAX, 
                        epsilon_decay = EXPLORATION_DECAY,
                        max_step = MAX_STEP)

#start time
q_learn_start = time.time()
# train Q-learning agent for 1000 episodes
q_learning_trainer.train(env, episode_count=1000, render=False)
# end time
q_learn_end = time.time()

q_learn_time = q_learn_end - q_learn_start
# Out:
# Ep: 0| Reward: 18 | Epsilon: 0.99
# Ep: 1| Reward: 24 | Epsilon: 0.99
# Ep: 2| Reward: 45 | Epsilon: 0.99
# Ep: 3| Reward: 24 | Epsilon: 0.98
# Ep: 4| Reward: 30 | Epsilon: 0.98
# Ep: 5| Reward: 18 | Epsilon: 0.97
# Ep: 6| Reward: 21 | Epsilon: 0.97
# Ep: 7| Reward: 16 | Epsilon: 0.96
# Ep: 8| Reward: 12 | Epsilon: 0.96
# Ep: 9| Reward: 31 | Epsilon: 0.95
# Ep: 10| Reward: 23 | Epsilon: 0.95
# Ep: 11| Reward: 10 | Epsilon: 0.94
# Ep: 12| Reward: 19 | Epsilon: 0.94
# Ep: 13| Reward: 11 | Epsilon: 0.93
# Ep: 14| Reward: 13 | Epsilon: 0.93
# Ep: 15| Reward: 20 | Epsilon: 0.92
# Ep: 16| Reward: 10 | Epsilon: 0.92
# Ep: 17| Reward: 13 | Epsilon: 0.91
# Ep: 18| Reward: 27 | Epsilon: 0.91
# Ep: 19| Reward: 17 | Epsilon: 0.9
# Ep: 20| Reward: 14 | Epsilon: 0.9
# Ep: 21| Reward: 13 | Epsilon: 0.9
# Ep: 22| Reward: 16 | Epsilon: 0.89
# Ep: 23| Reward: 42 | Epsilon: 0.89
# Ep: 24| Reward: 60 | Epsilon: 0.88
# Ep: 25| Reward: 14 | Epsilon: 0.88
# Ep: 26| Reward: 14 | Epsilon: 0.87
# Ep: 27| Reward: 22 | Epsilon: 0.87
# Ep: 28| Reward: 27 | Epsilon: 0.86
# Ep: 29| Reward: 38 | Epsilon: 0.86
# Ep: 30| Reward: 10 | Epsilon: 0.86
# Ep: 31| Reward: 10 | Epsilon: 0.85
# Ep: 32| Reward: 17 | Epsilon: 0.85
# Ep: 33| Reward: 52 | Epsilon: 0.84
# Ep: 34| Reward: 14 | Epsilon: 0.84
# Ep: 35| Reward: 10 | Epsilon: 0.83
# Ep: 36| Reward: 12 | Epsilon: 0.83
# Ep: 37| Reward: 21 | Epsilon: 0.83
# Ep: 38| Reward: 20 | Epsilon: 0.82
# Ep: 39| Reward: 45 | Epsilon: 0.82
# Ep: 40| Reward: 66 | Epsilon: 0.81
# Ep: 41| Reward: 31 | Epsilon: 0.81
# Ep: 42| Reward: 16 | Epsilon: 0.81
# Ep: 43| Reward: 14 | Epsilon: 0.8
# Ep: 44| Reward: 10 | Epsilon: 0.8
# Ep: 45| Reward: 33 | Epsilon: 0.79
# Ep: 46| Reward: 24 | Epsilon: 0.79
# Ep: 47| Reward: 9 | Epsilon: 0.79
# Ep: 48| Reward: 17 | Epsilon: 0.78
# Ep: 49| Reward: 20 | Epsilon: 0.78
# Ep: 50| Reward: 19 | Epsilon: 0.77
# Ep: 51| Reward: 11 | Epsilon: 0.77
# Ep: 52| Reward: 13 | Epsilon: 0.77
# Ep: 53| Reward: 30 | Epsilon: 0.76
# Ep: 54| Reward: 12 | Epsilon: 0.76
# Ep: 55| Reward: 12 | Epsilon: 0.76
# Ep: 56| Reward: 13 | Epsilon: 0.75
# Ep: 57| Reward: 20 | Epsilon: 0.75
# Ep: 58| Reward: 17 | Epsilon: 0.74
# Ep: 59| Reward: 14 | Epsilon: 0.74
# Ep: 60| Reward: 30 | Epsilon: 0.74
# Ep: 61| Reward: 20 | Epsilon: 0.73
# Ep: 62| Reward: 14 | Epsilon: 0.73
# Ep: 63| Reward: 23 | Epsilon: 0.73
# Ep: 64| Reward: 20 | Epsilon: 0.72
# Ep: 65| Reward: 15 | Epsilon: 0.72
# Ep: 66| Reward: 10 | Epsilon: 0.71
# Ep: 67| Reward: 24 | Epsilon: 0.71
# Ep: 68| Reward: 14 | Epsilon: 0.71
# Ep: 69| Reward: 10 | Epsilon: 0.7
# Ep: 70| Reward: 15 | Epsilon: 0.7
# Ep: 71| Reward: 27 | Epsilon: 0.7
# Ep: 72| Reward: 12 | Epsilon: 0.69
# Ep: 73| Reward: 26 | Epsilon: 0.69
# Ep: 74| Reward: 12 | Epsilon: 0.69
# Ep: 75| Reward: 40 | Epsilon: 0.68
# Ep: 76| Reward: 31 | Epsilon: 0.68
# Ep: 77| Reward: 31 | Epsilon: 0.68
# Ep: 78| Reward: 19 | Epsilon: 0.67
# Ep: 79| Reward: 17 | Epsilon: 0.67
# Ep: 80| Reward: 20 | Epsilon: 0.67
# Ep: 81| Reward: 19 | Epsilon: 0.66
# Ep: 82| Reward: 22 | Epsilon: 0.66
# Ep: 83| Reward: 14 | Epsilon: 0.66
# Ep: 84| Reward: 19 | Epsilon: 0.65
# Ep: 85| Reward: 12 | Epsilon: 0.65
# Ep: 86| Reward: 34 | Epsilon: 0.65
# Ep: 87| Reward: 53 | Epsilon: 0.64
# Ep: 88| Reward: 46 | Epsilon: 0.64
# Ep: 89| Reward: 11 | Epsilon: 0.64
# Ep: 90| Reward: 19 | Epsilon: 0.63
# Ep: 91| Reward: 28 | Epsilon: 0.63
# Ep: 92| Reward: 13 | Epsilon: 0.63
# Ep: 93| Reward: 21 | Epsilon: 0.62
# Ep: 94| Reward: 20 | Epsilon: 0.62
# Ep: 95| Reward: 22 | Epsilon: 0.62
# Ep: 96| Reward: 19 | Epsilon: 0.61
# Ep: 97| Reward: 12 | Epsilon: 0.61
# Ep: 98| Reward: 15 | Epsilon: 0.61
# Ep: 99| Reward: 17 | Epsilon: 0.61
# Ep: 100| Reward: 10 | Epsilon: 0.6
# Ep: 101| Reward: 31 | Epsilon: 0.6
# Ep: 102| Reward: 27 | Epsilon: 0.6
# Ep: 103| Reward: 47 | Epsilon: 0.59
# Ep: 104| Reward: 28 | Epsilon: 0.59
# Ep: 105| Reward: 20 | Epsilon: 0.59
# Ep: 106| Reward: 16 | Epsilon: 0.58
# Ep: 107| Reward: 24 | Epsilon: 0.58
# Ep: 108| Reward: 27 | Epsilon: 0.58
# Ep: 109| Reward: 52 | Epsilon: 0.58
# Ep: 110| Reward: 27 | Epsilon: 0.57
# Ep: 111| Reward: 13 | Epsilon: 0.57
# Ep: 112| Reward: 26 | Epsilon: 0.57
# Ep: 113| Reward: 12 | Epsilon: 0.56
# Ep: 114| Reward: 17 | Epsilon: 0.56
# Ep: 115| Reward: 10 | Epsilon: 0.56
# Ep: 116| Reward: 36 | Epsilon: 0.56
# Ep: 117| Reward: 19 | Epsilon: 0.55
# Ep: 118| Reward: 17 | Epsilon: 0.55
# Ep: 119| Reward: 36 | Epsilon: 0.55
# Ep: 120| Reward: 30 | Epsilon: 0.55
# Ep: 121| Reward: 21 | Epsilon: 0.54
# Ep: 122| Reward: 18 | Epsilon: 0.54
# Ep: 123| Reward: 20 | Epsilon: 0.54
# Ep: 124| Reward: 19 | Epsilon: 0.53
# Ep: 125| Reward: 14 | Epsilon: 0.53
# Ep: 126| Reward: 16 | Epsilon: 0.53
# Ep: 127| Reward: 9 | Epsilon: 0.53
# Ep: 128| Reward: 23 | Epsilon: 0.52
# Ep: 129| Reward: 15 | Epsilon: 0.52
# Ep: 130| Reward: 54 | Epsilon: 0.52
# Ep: 131| Reward: 40 | Epsilon: 0.52
# Ep: 132| Reward: 19 | Epsilon: 0.51
# Ep: 133| Reward: 18 | Epsilon: 0.51
# Ep: 134| Reward: 39 | Epsilon: 0.51
# Ep: 135| Reward: 32 | Epsilon: 0.51
# Ep: 136| Reward: 28 | Epsilon: 0.5
# Ep: 137| Reward: 30 | Epsilon: 0.5
# Ep: 138| Reward: 41 | Epsilon: 0.5
# Ep: 139| Reward: 26 | Epsilon: 0.5
# Ep: 140| Reward: 31 | Epsilon: 0.49
# Ep: 141| Reward: 11 | Epsilon: 0.49
# Ep: 142| Reward: 43 | Epsilon: 0.49
# Ep: 143| Reward: 19 | Epsilon: 0.49
# Ep: 144| Reward: 31 | Epsilon: 0.48
# Ep: 145| Reward: 30 | Epsilon: 0.48
# Ep: 146| Reward: 22 | Epsilon: 0.48
# Ep: 147| Reward: 9 | Epsilon: 0.48
# Ep: 148| Reward: 13 | Epsilon: 0.47
# Ep: 149| Reward: 18 | Epsilon: 0.47
# Ep: 150| Reward: 21 | Epsilon: 0.47
# Ep: 151| Reward: 12 | Epsilon: 0.47
# Ep: 152| Reward: 23 | Epsilon: 0.46
# Ep: 153| Reward: 46 | Epsilon: 0.46
# Ep: 154| Reward: 15 | Epsilon: 0.46
# Ep: 155| Reward: 45 | Epsilon: 0.46
# Ep: 156| Reward: 18 | Epsilon: 0.46
# Ep: 157| Reward: 10 | Epsilon: 0.45
# Ep: 158| Reward: 41 | Epsilon: 0.45
# Ep: 159| Reward: 39 | Epsilon: 0.45
# Ep: 160| Reward: 36 | Epsilon: 0.45
# Ep: 161| Reward: 28 | Epsilon: 0.44
# Ep: 162| Reward: 16 | Epsilon: 0.44
# Ep: 163| Reward: 22 | Epsilon: 0.44
# Ep: 164| Reward: 45 | Epsilon: 0.44
# Ep: 165| Reward: 27 | Epsilon: 0.44
# Ep: 166| Reward: 17 | Epsilon: 0.43
# Ep: 167| Reward: 11 | Epsilon: 0.43
# Ep: 168| Reward: 13 | Epsilon: 0.43
# Ep: 169| Reward: 24 | Epsilon: 0.43
# Ep: 170| Reward: 10 | Epsilon: 0.42
# Ep: 171| Reward: 15 | Epsilon: 0.42
# Ep: 172| Reward: 21 | Epsilon: 0.42
# Ep: 173| Reward: 13 | Epsilon: 0.42
# Ep: 174| Reward: 14 | Epsilon: 0.42
# Ep: 175| Reward: 20 | Epsilon: 0.41
# Ep: 176| Reward: 16 | Epsilon: 0.41
# Ep: 177| Reward: 9 | Epsilon: 0.41
# Ep: 178| Reward: 27 | Epsilon: 0.41
# Ep: 179| Reward: 45 | Epsilon: 0.41
# Ep: 180| Reward: 24 | Epsilon: 0.4
# Ep: 181| Reward: 27 | Epsilon: 0.4
# Ep: 182| Reward: 24 | Epsilon: 0.4
# Ep: 183| Reward: 23 | Epsilon: 0.4
# Ep: 184| Reward: 26 | Epsilon: 0.4
# Ep: 185| Reward: 40 | Epsilon: 0.39
# Ep: 186| Reward: 19 | Epsilon: 0.39
# Ep: 187| Reward: 22 | Epsilon: 0.39
# Ep: 188| Reward: 13 | Epsilon: 0.39
# Ep: 189| Reward: 30 | Epsilon: 0.39
# Ep: 190| Reward: 15 | Epsilon: 0.38
# Ep: 191| Reward: 23 | Epsilon: 0.38
# Ep: 192| Reward: 24 | Epsilon: 0.38
# Ep: 193| Reward: 22 | Epsilon: 0.38
# Ep: 194| Reward: 17 | Epsilon: 0.38
# Ep: 195| Reward: 17 | Epsilon: 0.37
# Ep: 196| Reward: 26 | Epsilon: 0.37
# Ep: 197| Reward: 11 | Epsilon: 0.37
# Ep: 198| Reward: 20 | Epsilon: 0.37
# Ep: 199| Reward: 17 | Epsilon: 0.37
# Ep: 200| Reward: 23 | Epsilon: 0.37
# Ep: 201| Reward: 14 | Epsilon: 0.36
# Ep: 202| Reward: 30 | Epsilon: 0.36
# Ep: 203| Reward: 13 | Epsilon: 0.36
# Ep: 204| Reward: 17 | Epsilon: 0.36
# Ep: 205| Reward: 38 | Epsilon: 0.36
# Ep: 206| Reward: 20 | Epsilon: 0.35
# Ep: 207| Reward: 14 | Epsilon: 0.35
# Ep: 208| Reward: 22 | Epsilon: 0.35
# Ep: 209| Reward: 12 | Epsilon: 0.35
# Ep: 210| Reward: 23 | Epsilon: 0.35
# Ep: 211| Reward: 21 | Epsilon: 0.35
# Ep: 212| Reward: 14 | Epsilon: 0.34
# Ep: 213| Reward: 23 | Epsilon: 0.34
# Ep: 214| Reward: 12 | Epsilon: 0.34
# Ep: 215| Reward: 14 | Epsilon: 0.34
# Ep: 216| Reward: 31 | Epsilon: 0.34
# Ep: 217| Reward: 11 | Epsilon: 0.34
# Ep: 218| Reward: 16 | Epsilon: 0.33
# Ep: 219| Reward: 41 | Epsilon: 0.33
# Ep: 220| Reward: 34 | Epsilon: 0.33
# Ep: 221| Reward: 16 | Epsilon: 0.33
# Ep: 222| Reward: 17 | Epsilon: 0.33
# Ep: 223| Reward: 14 | Epsilon: 0.33
# Ep: 224| Reward: 13 | Epsilon: 0.32
# Ep: 225| Reward: 28 | Epsilon: 0.32
# Ep: 226| Reward: 22 | Epsilon: 0.32
# Ep: 227| Reward: 25 | Epsilon: 0.32
# Ep: 228| Reward: 17 | Epsilon: 0.32
# Ep: 229| Reward: 29 | Epsilon: 0.32
# Ep: 230| Reward: 12 | Epsilon: 0.31
# Ep: 231| Reward: 22 | Epsilon: 0.31
# Ep: 232| Reward: 30 | Epsilon: 0.31
# Ep: 233| Reward: 12 | Epsilon: 0.31
# Ep: 234| Reward: 17 | Epsilon: 0.31
# Ep: 235| Reward: 39 | Epsilon: 0.31
# Ep: 236| Reward: 26 | Epsilon: 0.3
# Ep: 237| Reward: 19 | Epsilon: 0.3
# Ep: 238| Reward: 23 | Epsilon: 0.3
# Ep: 239| Reward: 15 | Epsilon: 0.3
# Ep: 240| Reward: 13 | Epsilon: 0.3
# Ep: 241| Reward: 14 | Epsilon: 0.3
# Ep: 242| Reward: 12 | Epsilon: 0.3
# Ep: 243| Reward: 20 | Epsilon: 0.29
# Ep: 244| Reward: 30 | Epsilon: 0.29
# Ep: 245| Reward: 25 | Epsilon: 0.29
# Ep: 246| Reward: 23 | Epsilon: 0.29
# Ep: 247| Reward: 19 | Epsilon: 0.29
# Ep: 248| Reward: 52 | Epsilon: 0.29
# Ep: 249| Reward: 14 | Epsilon: 0.29
# Ep: 250| Reward: 23 | Epsilon: 0.28
# Ep: 251| Reward: 11 | Epsilon: 0.28
# Ep: 252| Reward: 21 | Epsilon: 0.28
# Ep: 253| Reward: 14 | Epsilon: 0.28
# Ep: 254| Reward: 28 | Epsilon: 0.28
# Ep: 255| Reward: 14 | Epsilon: 0.28
# Ep: 256| Reward: 12 | Epsilon: 0.28
# Ep: 257| Reward: 13 | Epsilon: 0.27
# Ep: 258| Reward: 19 | Epsilon: 0.27
# Ep: 259| Reward: 16 | Epsilon: 0.27
# Ep: 260| Reward: 30 | Epsilon: 0.27
# Ep: 261| Reward: 17 | Epsilon: 0.27
# Ep: 262| Reward: 13 | Epsilon: 0.27
# Ep: 263| Reward: 21 | Epsilon: 0.27
# Ep: 264| Reward: 20 | Epsilon: 0.26
# Ep: 265| Reward: 17 | Epsilon: 0.26
# Ep: 266| Reward: 18 | Epsilon: 0.26
# Ep: 267| Reward: 21 | Epsilon: 0.26
# Ep: 268| Reward: 21 | Epsilon: 0.26
# Ep: 269| Reward: 13 | Epsilon: 0.26
# Ep: 270| Reward: 38 | Epsilon: 0.26
# Ep: 271| Reward: 15 | Epsilon: 0.26
# Ep: 272| Reward: 12 | Epsilon: 0.25
# Ep: 273| Reward: 16 | Epsilon: 0.25
# Ep: 274| Reward: 12 | Epsilon: 0.25
# Ep: 275| Reward: 13 | Epsilon: 0.25
# Ep: 276| Reward: 12 | Epsilon: 0.25
# Ep: 277| Reward: 25 | Epsilon: 0.25
# Ep: 278| Reward: 25 | Epsilon: 0.25
# Ep: 279| Reward: 15 | Epsilon: 0.25
# Ep: 280| Reward: 10 | Epsilon: 0.24
# Ep: 281| Reward: 32 | Epsilon: 0.24
# Ep: 282| Reward: 30 | Epsilon: 0.24
# Ep: 283| Reward: 47 | Epsilon: 0.24
# Ep: 284| Reward: 17 | Epsilon: 0.24
# Ep: 285| Reward: 17 | Epsilon: 0.24
# Ep: 286| Reward: 16 | Epsilon: 0.24
# Ep: 287| Reward: 26 | Epsilon: 0.24
# Ep: 288| Reward: 24 | Epsilon: 0.23
# Ep: 289| Reward: 16 | Epsilon: 0.23
# Ep: 290| Reward: 29 | Epsilon: 0.23
# Ep: 291| Reward: 38 | Epsilon: 0.23
# Ep: 292| Reward: 42 | Epsilon: 0.23
# Ep: 293| Reward: 19 | Epsilon: 0.23
# Ep: 294| Reward: 42 | Epsilon: 0.23
# Ep: 295| Reward: 20 | Epsilon: 0.23
# Ep: 296| Reward: 12 | Epsilon: 0.23
# Ep: 297| Reward: 46 | Epsilon: 0.22
# Ep: 298| Reward: 11 | Epsilon: 0.22
# Ep: 299| Reward: 34 | Epsilon: 0.22
# Ep: 300| Reward: 61 | Epsilon: 0.22
# Ep: 301| Reward: 10 | Epsilon: 0.22
# Ep: 302| Reward: 17 | Epsilon: 0.22
# Ep: 303| Reward: 10 | Epsilon: 0.22
# Ep: 304| Reward: 40 | Epsilon: 0.22
# Ep: 305| Reward: 13 | Epsilon: 0.22
# Ep: 306| Reward: 17 | Epsilon: 0.21
# Ep: 307| Reward: 13 | Epsilon: 0.21
# Ep: 308| Reward: 24 | Epsilon: 0.21
# Ep: 309| Reward: 22 | Epsilon: 0.21
# Ep: 310| Reward: 15 | Epsilon: 0.21
# Ep: 311| Reward: 11 | Epsilon: 0.21
# Ep: 312| Reward: 37 | Epsilon: 0.21
# Ep: 313| Reward: 20 | Epsilon: 0.21
# Ep: 314| Reward: 14 | Epsilon: 0.21
# Ep: 315| Reward: 121 | Epsilon: 0.21
# Ep: 316| Reward: 19 | Epsilon: 0.2
# Ep: 317| Reward: 81 | Epsilon: 0.2
# Ep: 318| Reward: 25 | Epsilon: 0.2
# Ep: 319| Reward: 12 | Epsilon: 0.2
# Ep: 320| Reward: 25 | Epsilon: 0.2
# Ep: 321| Reward: 35 | Epsilon: 0.2
# Ep: 322| Reward: 22 | Epsilon: 0.2
# Ep: 323| Reward: 22 | Epsilon: 0.2
# Ep: 324| Reward: 24 | Epsilon: 0.2
# Ep: 325| Reward: 18 | Epsilon: 0.2
# Ep: 326| Reward: 16 | Epsilon: 0.19
# Ep: 327| Reward: 10 | Epsilon: 0.19
# Ep: 328| Reward: 14 | Epsilon: 0.19
# Ep: 329| Reward: 19 | Epsilon: 0.19
# Ep: 330| Reward: 24 | Epsilon: 0.19
# Ep: 331| Reward: 18 | Epsilon: 0.19
# Ep: 332| Reward: 17 | Epsilon: 0.19
# Ep: 333| Reward: 23 | Epsilon: 0.19
# Ep: 334| Reward: 31 | Epsilon: 0.19
# Ep: 335| Reward: 23 | Epsilon: 0.19
# Ep: 336| Reward: 33 | Epsilon: 0.18
# Ep: 337| Reward: 27 | Epsilon: 0.18
# Ep: 338| Reward: 16 | Epsilon: 0.18
# Ep: 339| Reward: 14 | Epsilon: 0.18
# Ep: 340| Reward: 18 | Epsilon: 0.18
# Ep: 341| Reward: 37 | Epsilon: 0.18
# Ep: 342| Reward: 17 | Epsilon: 0.18
# Ep: 343| Reward: 18 | Epsilon: 0.18
# Ep: 344| Reward: 16 | Epsilon: 0.18
# Ep: 345| Reward: 15 | Epsilon: 0.18
# Ep: 346| Reward: 16 | Epsilon: 0.18
# Ep: 347| Reward: 41 | Epsilon: 0.17
# Ep: 348| Reward: 9 | Epsilon: 0.17
# Ep: 349| Reward: 33 | Epsilon: 0.17
# Ep: 350| Reward: 16 | Epsilon: 0.17
# Ep: 351| Reward: 35 | Epsilon: 0.17
# Ep: 352| Reward: 36 | Epsilon: 0.17
# Ep: 353| Reward: 25 | Epsilon: 0.17
# Ep: 354| Reward: 10 | Epsilon: 0.17
# Ep: 355| Reward: 15 | Epsilon: 0.17
# Ep: 356| Reward: 16 | Epsilon: 0.17
# Ep: 357| Reward: 10 | Epsilon: 0.17
# Ep: 358| Reward: 19 | Epsilon: 0.17
# Ep: 359| Reward: 16 | Epsilon: 0.16
# Ep: 360| Reward: 11 | Epsilon: 0.16
# Ep: 361| Reward: 26 | Epsilon: 0.16
# Ep: 362| Reward: 42 | Epsilon: 0.16
# Ep: 363| Reward: 30 | Epsilon: 0.16
# Ep: 364| Reward: 20 | Epsilon: 0.16
# Ep: 365| Reward: 48 | Epsilon: 0.16
# Ep: 366| Reward: 23 | Epsilon: 0.16
# Ep: 367| Reward: 89 | Epsilon: 0.16
# Ep: 368| Reward: 12 | Epsilon: 0.16
# Ep: 369| Reward: 21 | Epsilon: 0.16
# Ep: 370| Reward: 29 | Epsilon: 0.16
# Ep: 371| Reward: 22 | Epsilon: 0.15
# Ep: 372| Reward: 23 | Epsilon: 0.15
# Ep: 373| Reward: 60 | Epsilon: 0.15
# Ep: 374| Reward: 58 | Epsilon: 0.15
# Ep: 375| Reward: 12 | Epsilon: 0.15
# Ep: 376| Reward: 16 | Epsilon: 0.15
# Ep: 377| Reward: 19 | Epsilon: 0.15
# Ep: 378| Reward: 37 | Epsilon: 0.15
# Ep: 379| Reward: 22 | Epsilon: 0.15
# Ep: 380| Reward: 13 | Epsilon: 0.15
# Ep: 381| Reward: 38 | Epsilon: 0.15
# Ep: 382| Reward: 17 | Epsilon: 0.15
# Ep: 383| Reward: 10 | Epsilon: 0.15
# Ep: 384| Reward: 18 | Epsilon: 0.15
# Ep: 385| Reward: 20 | Epsilon: 0.14
# Ep: 386| Reward: 12 | Epsilon: 0.14
# Ep: 387| Reward: 31 | Epsilon: 0.14
# Ep: 388| Reward: 17 | Epsilon: 0.14
# Ep: 389| Reward: 38 | Epsilon: 0.14
# Ep: 390| Reward: 31 | Epsilon: 0.14
# Ep: 391| Reward: 19 | Epsilon: 0.14
# Ep: 392| Reward: 24 | Epsilon: 0.14
# Ep: 393| Reward: 15 | Epsilon: 0.14
# Ep: 394| Reward: 25 | Epsilon: 0.14
# Ep: 395| Reward: 68 | Epsilon: 0.14
# Ep: 396| Reward: 16 | Epsilon: 0.14
# Ep: 397| Reward: 21 | Epsilon: 0.14
# Ep: 398| Reward: 17 | Epsilon: 0.14
# Ep: 399| Reward: 66 | Epsilon: 0.13
# Ep: 400| Reward: 18 | Epsilon: 0.13
# Ep: 401| Reward: 34 | Epsilon: 0.13
# Ep: 402| Reward: 20 | Epsilon: 0.13
# Ep: 403| Reward: 19 | Epsilon: 0.13
# Ep: 404| Reward: 22 | Epsilon: 0.13
# Ep: 405| Reward: 19 | Epsilon: 0.13
# Ep: 406| Reward: 27 | Epsilon: 0.13
# Ep: 407| Reward: 14 | Epsilon: 0.13
# Ep: 408| Reward: 16 | Epsilon: 0.13
# Ep: 409| Reward: 33 | Epsilon: 0.13
# Ep: 410| Reward: 10 | Epsilon: 0.13
# Ep: 411| Reward: 29 | Epsilon: 0.13
# Ep: 412| Reward: 20 | Epsilon: 0.13
# Ep: 413| Reward: 16 | Epsilon: 0.13
# Ep: 414| Reward: 38 | Epsilon: 0.12
# Ep: 415| Reward: 54 | Epsilon: 0.12
# Ep: 416| Reward: 25 | Epsilon: 0.12
# Ep: 417| Reward: 54 | Epsilon: 0.12
# Ep: 418| Reward: 18 | Epsilon: 0.12
# Ep: 419| Reward: 30 | Epsilon: 0.12
# Ep: 420| Reward: 32 | Epsilon: 0.12
# Ep: 421| Reward: 34 | Epsilon: 0.12
# Ep: 422| Reward: 73 | Epsilon: 0.12
# Ep: 423| Reward: 34 | Epsilon: 0.12
# Ep: 424| Reward: 25 | Epsilon: 0.12
# Ep: 425| Reward: 17 | Epsilon: 0.12
# Ep: 426| Reward: 12 | Epsilon: 0.12
# Ep: 427| Reward: 12 | Epsilon: 0.12
# Ep: 428| Reward: 16 | Epsilon: 0.12
# Ep: 429| Reward: 14 | Epsilon: 0.12
# Ep: 430| Reward: 37 | Epsilon: 0.12
# Ep: 431| Reward: 9 | Epsilon: 0.11
# Ep: 432| Reward: 10 | Epsilon: 0.11
# Ep: 433| Reward: 64 | Epsilon: 0.11
# Ep: 434| Reward: 12 | Epsilon: 0.11
# Ep: 435| Reward: 12 | Epsilon: 0.11
# Ep: 436| Reward: 13 | Epsilon: 0.11
# Ep: 437| Reward: 10 | Epsilon: 0.11
# Ep: 438| Reward: 44 | Epsilon: 0.11
# Ep: 439| Reward: 32 | Epsilon: 0.11
# Ep: 440| Reward: 20 | Epsilon: 0.11
# Ep: 441| Reward: 14 | Epsilon: 0.11
# Ep: 442| Reward: 19 | Epsilon: 0.11
# Ep: 443| Reward: 22 | Epsilon: 0.11
# Ep: 444| Reward: 34 | Epsilon: 0.11
# Ep: 445| Reward: 20 | Epsilon: 0.11
# Ep: 446| Reward: 15 | Epsilon: 0.11
# Ep: 447| Reward: 18 | Epsilon: 0.11
# Ep: 448| Reward: 16 | Epsilon: 0.11
# Ep: 449| Reward: 28 | Epsilon: 0.1
# Ep: 450| Reward: 21 | Epsilon: 0.1
# Ep: 451| Reward: 40 | Epsilon: 0.1
# Ep: 452| Reward: 23 | Epsilon: 0.1
# Ep: 453| Reward: 21 | Epsilon: 0.1
# Ep: 454| Reward: 117 | Epsilon: 0.1
# Ep: 455| Reward: 49 | Epsilon: 0.1
# Ep: 456| Reward: 16 | Epsilon: 0.1
# Ep: 457| Reward: 16 | Epsilon: 0.1
# Ep: 458| Reward: 27 | Epsilon: 0.1
# Ep: 459| Reward: 30 | Epsilon: 0.1
# Ep: 460| Reward: 20 | Epsilon: 0.1
# Ep: 461| Reward: 17 | Epsilon: 0.1
# Ep: 462| Reward: 8 | Epsilon: 0.1
# Ep: 463| Reward: 11 | Epsilon: 0.1
# Ep: 464| Reward: 38 | Epsilon: 0.1
# Ep: 465| Reward: 17 | Epsilon: 0.1
# Ep: 466| Reward: 21 | Epsilon: 0.1
# Ep: 467| Reward: 19 | Epsilon: 0.1
# Ep: 468| Reward: 35 | Epsilon: 0.1
# Ep: 469| Reward: 23 | Epsilon: 0.09
# Ep: 470| Reward: 29 | Epsilon: 0.09
# Ep: 471| Reward: 10 | Epsilon: 0.09
# Ep: 472| Reward: 10 | Epsilon: 0.09
# Ep: 473| Reward: 20 | Epsilon: 0.09
# Ep: 474| Reward: 32 | Epsilon: 0.09
# Ep: 475| Reward: 21 | Epsilon: 0.09
# Ep: 476| Reward: 10 | Epsilon: 0.09
# Ep: 477| Reward: 28 | Epsilon: 0.09
# Ep: 478| Reward: 28 | Epsilon: 0.09
# Ep: 479| Reward: 18 | Epsilon: 0.09
# Ep: 480| Reward: 21 | Epsilon: 0.09
# Ep: 481| Reward: 8 | Epsilon: 0.09
# Ep: 482| Reward: 15 | Epsilon: 0.09
# Ep: 483| Reward: 13 | Epsilon: 0.09
# Ep: 484| Reward: 25 | Epsilon: 0.09
# Ep: 485| Reward: 24 | Epsilon: 0.09
# Ep: 486| Reward: 33 | Epsilon: 0.09
# Ep: 487| Reward: 13 | Epsilon: 0.09
# Ep: 488| Reward: 37 | Epsilon: 0.09
# Ep: 489| Reward: 14 | Epsilon: 0.09
# Ep: 490| Reward: 12 | Epsilon: 0.09
# Ep: 491| Reward: 34 | Epsilon: 0.08
# Ep: 492| Reward: 29 | Epsilon: 0.08
# Ep: 493| Reward: 9 | Epsilon: 0.08
# Ep: 494| Reward: 18 | Epsilon: 0.08
# Ep: 495| Reward: 18 | Epsilon: 0.08
# Ep: 496| Reward: 23 | Epsilon: 0.08
# Ep: 497| Reward: 41 | Epsilon: 0.08
# Ep: 498| Reward: 14 | Epsilon: 0.08
# Ep: 499| Reward: 27 | Epsilon: 0.08
# Ep: 500| Reward: 21 | Epsilon: 0.08
# Ep: 501| Reward: 21 | Epsilon: 0.08
# Ep: 502| Reward: 33 | Epsilon: 0.08
# Ep: 503| Reward: 23 | Epsilon: 0.08
# Ep: 504| Reward: 64 | Epsilon: 0.08
# Ep: 505| Reward: 26 | Epsilon: 0.08
# Ep: 506| Reward: 19 | Epsilon: 0.08
# Ep: 507| Reward: 26 | Epsilon: 0.08
# Ep: 508| Reward: 18 | Epsilon: 0.08
# Ep: 509| Reward: 16 | Epsilon: 0.08
# Ep: 510| Reward: 16 | Epsilon: 0.08
# Ep: 511| Reward: 13 | Epsilon: 0.08
# Ep: 512| Reward: 25 | Epsilon: 0.08
# Ep: 513| Reward: 92 | Epsilon: 0.08
# Ep: 514| Reward: 73 | Epsilon: 0.08
# Ep: 515| Reward: 32 | Epsilon: 0.08
# Ep: 516| Reward: 15 | Epsilon: 0.07
# Ep: 517| Reward: 33 | Epsilon: 0.07
# Ep: 518| Reward: 12 | Epsilon: 0.07
# Ep: 519| Reward: 10 | Epsilon: 0.07
# Ep: 520| Reward: 47 | Epsilon: 0.07
# Ep: 521| Reward: 35 | Epsilon: 0.07
# Ep: 522| Reward: 34 | Epsilon: 0.07
# Ep: 523| Reward: 18 | Epsilon: 0.07
# Ep: 524| Reward: 30 | Epsilon: 0.07
# Ep: 525| Reward: 26 | Epsilon: 0.07
# Ep: 526| Reward: 38 | Epsilon: 0.07
# Ep: 527| Reward: 15 | Epsilon: 0.07
# Ep: 528| Reward: 17 | Epsilon: 0.07
# Ep: 529| Reward: 28 | Epsilon: 0.07
# Ep: 530| Reward: 27 | Epsilon: 0.07
# Ep: 531| Reward: 20 | Epsilon: 0.07
# Ep: 532| Reward: 40 | Epsilon: 0.07
# Ep: 533| Reward: 27 | Epsilon: 0.07
# Ep: 534| Reward: 19 | Epsilon: 0.07
# Ep: 535| Reward: 15 | Epsilon: 0.07
# Ep: 536| Reward: 23 | Epsilon: 0.07
# Ep: 537| Reward: 31 | Epsilon: 0.07
# Ep: 538| Reward: 46 | Epsilon: 0.07
# Ep: 539| Reward: 12 | Epsilon: 0.07
# Ep: 540| Reward: 18 | Epsilon: 0.07
# Ep: 541| Reward: 16 | Epsilon: 0.07
# Ep: 542| Reward: 26 | Epsilon: 0.07
# Ep: 543| Reward: 25 | Epsilon: 0.07
# Ep: 544| Reward: 44 | Epsilon: 0.07
# Ep: 545| Reward: 14 | Epsilon: 0.06
# Ep: 546| Reward: 22 | Epsilon: 0.06
# Ep: 547| Reward: 15 | Epsilon: 0.06
# Ep: 548| Reward: 16 | Epsilon: 0.06
# Ep: 549| Reward: 29 | Epsilon: 0.06
# Ep: 550| Reward: 39 | Epsilon: 0.06
# Ep: 551| Reward: 42 | Epsilon: 0.06
# Ep: 552| Reward: 51 | Epsilon: 0.06
# Ep: 553| Reward: 69 | Epsilon: 0.06
# Ep: 554| Reward: 11 | Epsilon: 0.06
# Ep: 555| Reward: 33 | Epsilon: 0.06
# Ep: 556| Reward: 54 | Epsilon: 0.06
# Ep: 557| Reward: 12 | Epsilon: 0.06
# Ep: 558| Reward: 19 | Epsilon: 0.06
# Ep: 559| Reward: 12 | Epsilon: 0.06
# Ep: 560| Reward: 16 | Epsilon: 0.06
# Ep: 561| Reward: 17 | Epsilon: 0.06
# Ep: 562| Reward: 17 | Epsilon: 0.06
# Ep: 563| Reward: 22 | Epsilon: 0.06
# Ep: 564| Reward: 30 | Epsilon: 0.06
# Ep: 565| Reward: 16 | Epsilon: 0.06
# Ep: 566| Reward: 17 | Epsilon: 0.06
# Ep: 567| Reward: 23 | Epsilon: 0.06
# Ep: 568| Reward: 44 | Epsilon: 0.06
# Ep: 569| Reward: 22 | Epsilon: 0.06
# Ep: 570| Reward: 16 | Epsilon: 0.06
# Ep: 571| Reward: 29 | Epsilon: 0.06
# Ep: 572| Reward: 15 | Epsilon: 0.06
# Ep: 573| Reward: 56 | Epsilon: 0.06
# Ep: 574| Reward: 16 | Epsilon: 0.06
# Ep: 575| Reward: 74 | Epsilon: 0.06
# Ep: 576| Reward: 10 | Epsilon: 0.06
# Ep: 577| Reward: 20 | Epsilon: 0.06
# Ep: 578| Reward: 18 | Epsilon: 0.05
# Ep: 579| Reward: 12 | Epsilon: 0.05
# Ep: 580| Reward: 10 | Epsilon: 0.05
# Ep: 581| Reward: 29 | Epsilon: 0.05
# Ep: 582| Reward: 16 | Epsilon: 0.05
# Ep: 583| Reward: 12 | Epsilon: 0.05
# Ep: 584| Reward: 29 | Epsilon: 0.05
# Ep: 585| Reward: 8 | Epsilon: 0.05
# Ep: 586| Reward: 25 | Epsilon: 0.05
# Ep: 587| Reward: 63 | Epsilon: 0.05
# Ep: 588| Reward: 41 | Epsilon: 0.05
# Ep: 589| Reward: 35 | Epsilon: 0.05
# Ep: 590| Reward: 14 | Epsilon: 0.05
# Ep: 591| Reward: 15 | Epsilon: 0.05
# Ep: 592| Reward: 13 | Epsilon: 0.05
# Ep: 593| Reward: 24 | Epsilon: 0.05
# Ep: 594| Reward: 57 | Epsilon: 0.05
# Ep: 595| Reward: 18 | Epsilon: 0.05
# Ep: 596| Reward: 17 | Epsilon: 0.05
# Ep: 597| Reward: 26 | Epsilon: 0.05
# Ep: 598| Reward: 16 | Epsilon: 0.05
# Ep: 599| Reward: 15 | Epsilon: 0.05
# Ep: 600| Reward: 22 | Epsilon: 0.05
# Ep: 601| Reward: 31 | Epsilon: 0.05
# Ep: 602| Reward: 42 | Epsilon: 0.05
# Ep: 603| Reward: 21 | Epsilon: 0.05
# Ep: 604| Reward: 34 | Epsilon: 0.05
# Ep: 605| Reward: 12 | Epsilon: 0.05
# Ep: 606| Reward: 15 | Epsilon: 0.05
# Ep: 607| Reward: 16 | Epsilon: 0.05
# Ep: 608| Reward: 34 | Epsilon: 0.05
# Ep: 609| Reward: 24 | Epsilon: 0.05
# Ep: 610| Reward: 89 | Epsilon: 0.05
# Ep: 611| Reward: 31 | Epsilon: 0.05
# Ep: 612| Reward: 17 | Epsilon: 0.05
# Ep: 613| Reward: 35 | Epsilon: 0.05
# Ep: 614| Reward: 42 | Epsilon: 0.05
# Ep: 615| Reward: 51 | Epsilon: 0.05
# Ep: 616| Reward: 31 | Epsilon: 0.05
# Ep: 617| Reward: 10 | Epsilon: 0.05
# Ep: 618| Reward: 31 | Epsilon: 0.04
# Ep: 619| Reward: 14 | Epsilon: 0.04
# Ep: 620| Reward: 16 | Epsilon: 0.04
# Ep: 621| Reward: 23 | Epsilon: 0.04
# Ep: 622| Reward: 17 | Epsilon: 0.04
# Ep: 623| Reward: 120 | Epsilon: 0.04
# Ep: 624| Reward: 20 | Epsilon: 0.04
# Ep: 625| Reward: 19 | Epsilon: 0.04
# Ep: 626| Reward: 32 | Epsilon: 0.04
# Ep: 627| Reward: 15 | Epsilon: 0.04
# Ep: 628| Reward: 35 | Epsilon: 0.04
# Ep: 629| Reward: 17 | Epsilon: 0.04
# Ep: 630| Reward: 22 | Epsilon: 0.04
# Ep: 631| Reward: 13 | Epsilon: 0.04
# Ep: 632| Reward: 25 | Epsilon: 0.04
# Ep: 633| Reward: 45 | Epsilon: 0.04
# Ep: 634| Reward: 18 | Epsilon: 0.04
# Ep: 635| Reward: 10 | Epsilon: 0.04
# Ep: 636| Reward: 16 | Epsilon: 0.04
# Ep: 637| Reward: 16 | Epsilon: 0.04
# Ep: 638| Reward: 15 | Epsilon: 0.04
# Ep: 639| Reward: 19 | Epsilon: 0.04
# Ep: 640| Reward: 24 | Epsilon: 0.04
# Ep: 641| Reward: 39 | Epsilon: 0.04
# Ep: 642| Reward: 12 | Epsilon: 0.04
# Ep: 643| Reward: 23 | Epsilon: 0.04
# Ep: 644| Reward: 36 | Epsilon: 0.04
# Ep: 645| Reward: 38 | Epsilon: 0.04
# Ep: 646| Reward: 16 | Epsilon: 0.04
# Ep: 647| Reward: 47 | Epsilon: 0.04
# Ep: 648| Reward: 16 | Epsilon: 0.04
# Ep: 649| Reward: 49 | Epsilon: 0.04
# Ep: 650| Reward: 17 | Epsilon: 0.04
# Ep: 651| Reward: 21 | Epsilon: 0.04
# Ep: 652| Reward: 17 | Epsilon: 0.04
# Ep: 653| Reward: 23 | Epsilon: 0.04
# Ep: 654| Reward: 72 | Epsilon: 0.04
# Ep: 655| Reward: 20 | Epsilon: 0.04
# Ep: 656| Reward: 16 | Epsilon: 0.04
# Ep: 657| Reward: 64 | Epsilon: 0.04
# Ep: 658| Reward: 16 | Epsilon: 0.04
# Ep: 659| Reward: 24 | Epsilon: 0.04
# Ep: 660| Reward: 13 | Epsilon: 0.04
# Ep: 661| Reward: 15 | Epsilon: 0.04
# Ep: 662| Reward: 16 | Epsilon: 0.04
# Ep: 663| Reward: 18 | Epsilon: 0.04
# Ep: 664| Reward: 76 | Epsilon: 0.04
# Ep: 665| Reward: 13 | Epsilon: 0.04
# Ep: 666| Reward: 20 | Epsilon: 0.04
# Ep: 667| Reward: 61 | Epsilon: 0.04
# Ep: 668| Reward: 22 | Epsilon: 0.03
# Ep: 669| Reward: 30 | Epsilon: 0.03
# Ep: 670| Reward: 18 | Epsilon: 0.03
# Ep: 671| Reward: 23 | Epsilon: 0.03
# Ep: 672| Reward: 14 | Epsilon: 0.03
# Ep: 673| Reward: 55 | Epsilon: 0.03
# Ep: 674| Reward: 25 | Epsilon: 0.03
# Ep: 675| Reward: 44 | Epsilon: 0.03
# Ep: 676| Reward: 14 | Epsilon: 0.03
# Ep: 677| Reward: 35 | Epsilon: 0.03
# Ep: 678| Reward: 17 | Epsilon: 0.03
# Ep: 679| Reward: 50 | Epsilon: 0.03
# Ep: 680| Reward: 24 | Epsilon: 0.03
# Ep: 681| Reward: 12 | Epsilon: 0.03
# Ep: 682| Reward: 40 | Epsilon: 0.03
# Ep: 683| Reward: 38 | Epsilon: 0.03
# Ep: 684| Reward: 49 | Epsilon: 0.03
# Ep: 685| Reward: 22 | Epsilon: 0.03
# Ep: 686| Reward: 30 | Epsilon: 0.03
# Ep: 687| Reward: 12 | Epsilon: 0.03
# Ep: 688| Reward: 15 | Epsilon: 0.03
# Ep: 689| Reward: 20 | Epsilon: 0.03
# Ep: 690| Reward: 12 | Epsilon: 0.03
# Ep: 691| Reward: 86 | Epsilon: 0.03
# Ep: 692| Reward: 18 | Epsilon: 0.03
# Ep: 693| Reward: 18 | Epsilon: 0.03
# Ep: 694| Reward: 41 | Epsilon: 0.03
# Ep: 695| Reward: 18 | Epsilon: 0.03
# Ep: 696| Reward: 18 | Epsilon: 0.03
# Ep: 697| Reward: 18 | Epsilon: 0.03
# Ep: 698| Reward: 25 | Epsilon: 0.03
# Ep: 699| Reward: 50 | Epsilon: 0.03
# Ep: 700| Reward: 20 | Epsilon: 0.03
# Ep: 701| Reward: 22 | Epsilon: 0.03
# Ep: 702| Reward: 30 | Epsilon: 0.03
# Ep: 703| Reward: 13 | Epsilon: 0.03
# Ep: 704| Reward: 52 | Epsilon: 0.03
# Ep: 705| Reward: 20 | Epsilon: 0.03
# Ep: 706| Reward: 33 | Epsilon: 0.03
# Ep: 707| Reward: 49 | Epsilon: 0.03
# Ep: 708| Reward: 13 | Epsilon: 0.03
# Ep: 709| Reward: 37 | Epsilon: 0.03
# Ep: 710| Reward: 23 | Epsilon: 0.03
# Ep: 711| Reward: 25 | Epsilon: 0.03
# Ep: 712| Reward: 28 | Epsilon: 0.03
# Ep: 713| Reward: 12 | Epsilon: 0.03
# Ep: 714| Reward: 25 | Epsilon: 0.03
# Ep: 715| Reward: 40 | Epsilon: 0.03
# Ep: 716| Reward: 17 | Epsilon: 0.03
# Ep: 717| Reward: 18 | Epsilon: 0.03
# Ep: 718| Reward: 12 | Epsilon: 0.03
# Ep: 719| Reward: 29 | Epsilon: 0.03
# Ep: 720| Reward: 34 | Epsilon: 0.03
# Ep: 721| Reward: 28 | Epsilon: 0.03
# Ep: 722| Reward: 44 | Epsilon: 0.03
# Ep: 723| Reward: 28 | Epsilon: 0.03
# Ep: 724| Reward: 34 | Epsilon: 0.03
# Ep: 725| Reward: 27 | Epsilon: 0.03
# Ep: 726| Reward: 42 | Epsilon: 0.03
# Ep: 727| Reward: 23 | Epsilon: 0.03
# Ep: 728| Reward: 55 | Epsilon: 0.03
# Ep: 729| Reward: 32 | Epsilon: 0.03
# Ep: 730| Reward: 15 | Epsilon: 0.03
# Ep: 731| Reward: 20 | Epsilon: 0.03
# Ep: 732| Reward: 116 | Epsilon: 0.03
# Ep: 733| Reward: 22 | Epsilon: 0.03
# Ep: 734| Reward: 22 | Epsilon: 0.03
# Ep: 735| Reward: 20 | Epsilon: 0.02
# Ep: 736| Reward: 82 | Epsilon: 0.02
# Ep: 737| Reward: 22 | Epsilon: 0.02
# Ep: 738| Reward: 14 | Epsilon: 0.02
# Ep: 739| Reward: 54 | Epsilon: 0.02
# Ep: 740| Reward: 17 | Epsilon: 0.02
# Ep: 741| Reward: 8 | Epsilon: 0.02
# Ep: 742| Reward: 38 | Epsilon: 0.02
# Ep: 743| Reward: 106 | Epsilon: 0.02
# Ep: 744| Reward: 17 | Epsilon: 0.02
# Ep: 745| Reward: 20 | Epsilon: 0.02
# Ep: 746| Reward: 17 | Epsilon: 0.02
# Ep: 747| Reward: 13 | Epsilon: 0.02
# Ep: 748| Reward: 21 | Epsilon: 0.02
# Ep: 749| Reward: 12 | Epsilon: 0.02
# Ep: 750| Reward: 19 | Epsilon: 0.02
# Ep: 751| Reward: 14 | Epsilon: 0.02
# Ep: 752| Reward: 17 | Epsilon: 0.02
# Ep: 753| Reward: 17 | Epsilon: 0.02
# Ep: 754| Reward: 84 | Epsilon: 0.02
# Ep: 755| Reward: 14 | Epsilon: 0.02
# Ep: 756| Reward: 29 | Epsilon: 0.02
# Ep: 757| Reward: 60 | Epsilon: 0.02
# Ep: 758| Reward: 21 | Epsilon: 0.02
# Ep: 759| Reward: 25 | Epsilon: 0.02
# Ep: 760| Reward: 52 | Epsilon: 0.02
# Ep: 761| Reward: 12 | Epsilon: 0.02
# Ep: 762| Reward: 49 | Epsilon: 0.02
# Ep: 763| Reward: 50 | Epsilon: 0.02
# Ep: 764| Reward: 25 | Epsilon: 0.02
# Ep: 765| Reward: 101 | Epsilon: 0.02
# Ep: 766| Reward: 38 | Epsilon: 0.02
# Ep: 767| Reward: 21 | Epsilon: 0.02
# Ep: 768| Reward: 17 | Epsilon: 0.02
# Ep: 769| Reward: 25 | Epsilon: 0.02
# Ep: 770| Reward: 41 | Epsilon: 0.02
# Ep: 771| Reward: 16 | Epsilon: 0.02
# Ep: 772| Reward: 27 | Epsilon: 0.02
# Ep: 773| Reward: 124 | Epsilon: 0.02
# Ep: 774| Reward: 18 | Epsilon: 0.02
# Ep: 775| Reward: 29 | Epsilon: 0.02
# Ep: 776| Reward: 25 | Epsilon: 0.02
# Ep: 777| Reward: 26 | Epsilon: 0.02
# Ep: 778| Reward: 46 | Epsilon: 0.02
# Ep: 779| Reward: 162 | Epsilon: 0.02
# Ep: 780| Reward: 10 | Epsilon: 0.02
# Ep: 781| Reward: 22 | Epsilon: 0.02
# Ep: 782| Reward: 54 | Epsilon: 0.02
# Ep: 783| Reward: 26 | Epsilon: 0.02
# Ep: 784| Reward: 52 | Epsilon: 0.02
# Ep: 785| Reward: 27 | Epsilon: 0.02
# Ep: 786| Reward: 43 | Epsilon: 0.02
# Ep: 787| Reward: 20 | Epsilon: 0.02
# Ep: 788| Reward: 15 | Epsilon: 0.02
# Ep: 789| Reward: 17 | Epsilon: 0.02
# Ep: 790| Reward: 18 | Epsilon: 0.02
# Ep: 791| Reward: 65 | Epsilon: 0.02
# Ep: 792| Reward: 21 | Epsilon: 0.02
# Ep: 793| Reward: 31 | Epsilon: 0.02
# Ep: 794| Reward: 101 | Epsilon: 0.02
# Ep: 795| Reward: 16 | Epsilon: 0.02
# Ep: 796| Reward: 15 | Epsilon: 0.02
# Ep: 797| Reward: 38 | Epsilon: 0.02
# Ep: 798| Reward: 22 | Epsilon: 0.02
# Ep: 799| Reward: 14 | Epsilon: 0.02
# Ep: 800| Reward: 53 | Epsilon: 0.02
# Ep: 801| Reward: 46 | Epsilon: 0.02
# Ep: 802| Reward: 30 | Epsilon: 0.02
# Ep: 803| Reward: 12 | Epsilon: 0.02
# Ep: 804| Reward: 52 | Epsilon: 0.02
# Ep: 805| Reward: 18 | Epsilon: 0.02
# Ep: 806| Reward: 15 | Epsilon: 0.02
# Ep: 807| Reward: 17 | Epsilon: 0.02
# Ep: 808| Reward: 28 | Epsilon: 0.02
# Ep: 809| Reward: 15 | Epsilon: 0.02
# Ep: 810| Reward: 20 | Epsilon: 0.02
# Ep: 811| Reward: 27 | Epsilon: 0.02
# Ep: 812| Reward: 31 | Epsilon: 0.02
# Ep: 813| Reward: 29 | Epsilon: 0.02
# Ep: 814| Reward: 29 | Epsilon: 0.02
# Ep: 815| Reward: 54 | Epsilon: 0.02
# Ep: 816| Reward: 21 | Epsilon: 0.02
# Ep: 817| Reward: 91 | Epsilon: 0.02
# Ep: 818| Reward: 38 | Epsilon: 0.02
# Ep: 819| Reward: 44 | Epsilon: 0.02
# Ep: 820| Reward: 8 | Epsilon: 0.02
# Ep: 821| Reward: 18 | Epsilon: 0.02
# Ep: 822| Reward: 50 | Epsilon: 0.02
# Ep: 823| Reward: 15 | Epsilon: 0.02
# Ep: 824| Reward: 60 | Epsilon: 0.02
# Ep: 825| Reward: 70 | Epsilon: 0.02
# Ep: 826| Reward: 18 | Epsilon: 0.02
# Ep: 827| Reward: 21 | Epsilon: 0.02
# Ep: 828| Reward: 16 | Epsilon: 0.02
# Ep: 829| Reward: 18 | Epsilon: 0.02
# Ep: 830| Reward: 15 | Epsilon: 0.02
# Ep: 831| Reward: 29 | Epsilon: 0.02
# Ep: 832| Reward: 22 | Epsilon: 0.02
# Ep: 833| Reward: 80 | Epsilon: 0.02
# Ep: 834| Reward: 15 | Epsilon: 0.02
# Ep: 835| Reward: 18 | Epsilon: 0.02
# Ep: 836| Reward: 25 | Epsilon: 0.02
# Ep: 837| Reward: 27 | Epsilon: 0.01
# Ep: 838| Reward: 16 | Epsilon: 0.01
# Ep: 839| Reward: 22 | Epsilon: 0.01
# Ep: 840| Reward: 26 | Epsilon: 0.01
# Ep: 841| Reward: 20 | Epsilon: 0.01
# Ep: 842| Reward: 12 | Epsilon: 0.01
# Ep: 843| Reward: 19 | Epsilon: 0.01
# Ep: 844| Reward: 19 | Epsilon: 0.01
# Ep: 845| Reward: 12 | Epsilon: 0.01
# Ep: 846| Reward: 48 | Epsilon: 0.01
# Ep: 847| Reward: 34 | Epsilon: 0.01
# Ep: 848| Reward: 20 | Epsilon: 0.01
# Ep: 849| Reward: 24 | Epsilon: 0.01
# Ep: 850| Reward: 19 | Epsilon: 0.01
# Ep: 851| Reward: 14 | Epsilon: 0.01
# Ep: 852| Reward: 20 | Epsilon: 0.01
# Ep: 853| Reward: 95 | Epsilon: 0.01
# Ep: 854| Reward: 15 | Epsilon: 0.01
# Ep: 855| Reward: 29 | Epsilon: 0.01
# Ep: 856| Reward: 29 | Epsilon: 0.01
# Ep: 857| Reward: 40 | Epsilon: 0.01
# Ep: 858| Reward: 20 | Epsilon: 0.01
# Ep: 859| Reward: 16 | Epsilon: 0.01
# Ep: 860| Reward: 20 | Epsilon: 0.01
# Ep: 861| Reward: 67 | Epsilon: 0.01
# Ep: 862| Reward: 22 | Epsilon: 0.01
# Ep: 863| Reward: 45 | Epsilon: 0.01
# Ep: 864| Reward: 32 | Epsilon: 0.01
# Ep: 865| Reward: 55 | Epsilon: 0.01
# Ep: 866| Reward: 54 | Epsilon: 0.01
# Ep: 867| Reward: 24 | Epsilon: 0.01
# Ep: 868| Reward: 36 | Epsilon: 0.01
# Ep: 869| Reward: 100 | Epsilon: 0.01
# Ep: 870| Reward: 18 | Epsilon: 0.01
# Ep: 871| Reward: 21 | Epsilon: 0.01
# Ep: 872| Reward: 192 | Epsilon: 0.01
# Ep: 873| Reward: 57 | Epsilon: 0.01
# Ep: 874| Reward: 43 | Epsilon: 0.01
# Ep: 875| Reward: 22 | Epsilon: 0.01
# Ep: 876| Reward: 19 | Epsilon: 0.01
# Ep: 877| Reward: 15 | Epsilon: 0.01
# Ep: 878| Reward: 44 | Epsilon: 0.01
# Ep: 879| Reward: 14 | Epsilon: 0.01
# Ep: 880| Reward: 17 | Epsilon: 0.01
# Ep: 881| Reward: 26 | Epsilon: 0.01
# Ep: 882| Reward: 22 | Epsilon: 0.01
# Ep: 883| Reward: 28 | Epsilon: 0.01
# Ep: 884| Reward: 40 | Epsilon: 0.01
# Ep: 885| Reward: 20 | Epsilon: 0.01
# Ep: 886| Reward: 34 | Epsilon: 0.01
# Ep: 887| Reward: 14 | Epsilon: 0.01
# Ep: 888| Reward: 20 | Epsilon: 0.01
# Ep: 889| Reward: 18 | Epsilon: 0.01
# Ep: 890| Reward: 43 | Epsilon: 0.01
# Ep: 891| Reward: 29 | Epsilon: 0.01
# Ep: 892| Reward: 19 | Epsilon: 0.01
# Ep: 893| Reward: 29 | Epsilon: 0.01
# Ep: 894| Reward: 23 | Epsilon: 0.01
# Ep: 895| Reward: 20 | Epsilon: 0.01
# Ep: 896| Reward: 27 | Epsilon: 0.01
# Ep: 897| Reward: 40 | Epsilon: 0.01
# Ep: 898| Reward: 36 | Epsilon: 0.01
# Ep: 899| Reward: 27 | Epsilon: 0.01
# Ep: 900| Reward: 89 | Epsilon: 0.01
# Ep: 901| Reward: 26 | Epsilon: 0.01
# Ep: 902| Reward: 25 | Epsilon: 0.01
# Ep: 903| Reward: 17 | Epsilon: 0.01
# Ep: 904| Reward: 15 | Epsilon: 0.01
# Ep: 905| Reward: 40 | Epsilon: 0.01
# Ep: 906| Reward: 22 | Epsilon: 0.01
# Ep: 907| Reward: 63 | Epsilon: 0.01
# Ep: 908| Reward: 18 | Epsilon: 0.01
# Ep: 909| Reward: 17 | Epsilon: 0.01
# Ep: 910| Reward: 14 | Epsilon: 0.01
# Ep: 911| Reward: 30 | Epsilon: 0.01
# Ep: 912| Reward: 20 | Epsilon: 0.01
# Ep: 913| Reward: 16 | Epsilon: 0.01
# Ep: 914| Reward: 23 | Epsilon: 0.01
# Ep: 915| Reward: 12 | Epsilon: 0.01
# Ep: 916| Reward: 52 | Epsilon: 0.01
# Ep: 917| Reward: 26 | Epsilon: 0.01
# Ep: 918| Reward: 20 | Epsilon: 0.01
# Ep: 919| Reward: 21 | Epsilon: 0.01
# Ep: 920| Reward: 42 | Epsilon: 0.01
# Ep: 921| Reward: 46 | Epsilon: 0.01
# Ep: 922| Reward: 32 | Epsilon: 0.01
# Ep: 923| Reward: 38 | Epsilon: 0.01
# Ep: 924| Reward: 22 | Epsilon: 0.01
# Ep: 925| Reward: 26 | Epsilon: 0.01
# Ep: 926| Reward: 23 | Epsilon: 0.01
# Ep: 927| Reward: 40 | Epsilon: 0.01
# Ep: 928| Reward: 12 | Epsilon: 0.01
# Ep: 929| Reward: 19 | Epsilon: 0.01
# Ep: 930| Reward: 150 | Epsilon: 0.01
# Ep: 931| Reward: 52 | Epsilon: 0.01
# Ep: 932| Reward: 17 | Epsilon: 0.01
# Ep: 933| Reward: 12 | Epsilon: 0.01
# Ep: 934| Reward: 18 | Epsilon: 0.01
# Ep: 935| Reward: 31 | Epsilon: 0.01
# Ep: 936| Reward: 18 | Epsilon: 0.01
# Ep: 937| Reward: 54 | Epsilon: 0.01
# Ep: 938| Reward: 31 | Epsilon: 0.01
# Ep: 939| Reward: 32 | Epsilon: 0.01
# Ep: 940| Reward: 27 | Epsilon: 0.01
# Ep: 941| Reward: 19 | Epsilon: 0.01
# Ep: 942| Reward: 25 | Epsilon: 0.01
# Ep: 943| Reward: 42 | Epsilon: 0.01
# Ep: 944| Reward: 24 | Epsilon: 0.01
# Ep: 945| Reward: 24 | Epsilon: 0.01
# Ep: 946| Reward: 25 | Epsilon: 0.01
# Ep: 947| Reward: 38 | Epsilon: 0.01
# Ep: 948| Reward: 24 | Epsilon: 0.01
# Ep: 949| Reward: 21 | Epsilon: 0.01
# Ep: 950| Reward: 19 | Epsilon: 0.01
# Ep: 951| Reward: 18 | Epsilon: 0.01
# Ep: 952| Reward: 33 | Epsilon: 0.01
# Ep: 953| Reward: 22 | Epsilon: 0.01
# Ep: 954| Reward: 15 | Epsilon: 0.01
# Ep: 955| Reward: 27 | Epsilon: 0.01
# Ep: 956| Reward: 24 | Epsilon: 0.01
# Ep: 957| Reward: 113 | Epsilon: 0.01
# Ep: 958| Reward: 24 | Epsilon: 0.01
# Ep: 959| Reward: 20 | Epsilon: 0.01
# Ep: 960| Reward: 43 | Epsilon: 0.01
# Ep: 961| Reward: 48 | Epsilon: 0.01
# Ep: 962| Reward: 16 | Epsilon: 0.01
# Ep: 963| Reward: 16 | Epsilon: 0.01
# Ep: 964| Reward: 42 | Epsilon: 0.01
# Ep: 965| Reward: 20 | Epsilon: 0.01
# Ep: 966| Reward: 15 | Epsilon: 0.01
# Ep: 967| Reward: 20 | Epsilon: 0.01
# Ep: 968| Reward: 25 | Epsilon: 0.01
# Ep: 969| Reward: 14 | Epsilon: 0.01
# Ep: 970| Reward: 64 | Epsilon: 0.01
# Ep: 971| Reward: 27 | Epsilon: 0.01
# Ep: 972| Reward: 31 | Epsilon: 0.01
# Ep: 973| Reward: 14 | Epsilon: 0.01
# Ep: 974| Reward: 37 | Epsilon: 0.01
# Ep: 975| Reward: 15 | Epsilon: 0.01
# Ep: 976| Reward: 22 | Epsilon: 0.01
# Ep: 977| Reward: 28 | Epsilon: 0.01
# Ep: 978| Reward: 34 | Epsilon: 0.01
# Ep: 979| Reward: 35 | Epsilon: 0.01
# Ep: 980| Reward: 20 | Epsilon: 0.01
# Ep: 981| Reward: 19 | Epsilon: 0.01
# Ep: 982| Reward: 48 | Epsilon: 0.01
# Ep: 983| Reward: 18 | Epsilon: 0.01
# Ep: 984| Reward: 16 | Epsilon: 0.01
# Ep: 985| Reward: 19 | Epsilon: 0.01
# Ep: 986| Reward: 19 | Epsilon: 0.01
# Ep: 987| Reward: 33 | Epsilon: 0.01
# Ep: 988| Reward: 46 | Epsilon: 0.01
# Ep: 989| Reward: 19 | Epsilon: 0.01
# Ep: 990| Reward: 18 | Epsilon: 0.01
# Ep: 991| Reward: 10 | Epsilon: 0.01
# Ep: 992| Reward: 46 | Epsilon: 0.01
# Ep: 993| Reward: 40 | Epsilon: 0.01
# Ep: 994| Reward: 40 | Epsilon: 0.01
# Ep: 995| Reward: 48 | Epsilon: 0.01
# Ep: 996| Reward: 52 | Epsilon: 0.01
# Ep: 997| Reward: 29 | Epsilon: 0.01
# Ep: 998| Reward: 25 | Epsilon: 0.01
# Ep: 999| Reward: 22 | Epsilon: 0.01

# %% [markdown]
# # Deep Q-Network (DQN)
#
# DQN makes use of a neural network as a univeresal function approximator. This allows us to approximate a value function over a continuous state space, and so find the optimal value function without having to discretize the state space.

# %%
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

class DQN_agent:
    '''
    Reference: https://github.com/gsurma/cartpole/blob/master/cartpole.py
    DQN Agent with epsilon greedy policy.
    The neural network consists of 3 fully-connected layers.
    ''' 

    def __init__(self, observation_space, action_space):
        
        
        self.epsilon = EXPLORATION_MAX
        self.action_space = action_space
        self.observation_space = observation_space
        
        # neural network model
        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))
        
        # experience replay memory
        self.memory = deque(maxlen=MEMORY_SIZE)

       
    def act(self, state):
        
        action = -1
        state = np.reshape(state, [1, self.observation_space])
        
        if np.random.rand() < self.epsilon:
            # randomly select action from action space
            action = random.randrange(self.action_space)
        else:
            # get probability distribution of best action-value given current state
            q_values = self.model.predict(state)
            # get action with highest reward value
            action = np.argmax(q_values[0])
        
        return action
    
    
    def remember(self, state, action, reward, next_state, done):
        
        # store transition in exp replay memory
        self.memory.append((state, action, reward, next_state, done))
        

    def experience_replay(self):
        
        if len(self.memory) < BATCH_SIZE:
            return
        
        # sample random minibatch of transitions
        batch = random.sample(self.memory, BATCH_SIZE)
        
        for state, action, reward, state_next, done in batch:
            
            q_update = reward
            
            if not done:
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
            
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
# Out:
# Using TensorFlow backend.

# %%
class DQN_Trainer(Trainer):
    
    '''
    The DQN trainer inherits from the Q-learning trainer class.
    The update method is modified to store transitions in 
    experience replay memory.
    '''

    def update(self, obs, action, reward, next_obs, done):
        '''
        Update DQN Agent.
        '''
        # modify reward, obs, and next obs
        reward = reward if not done else -reward
        obs = np.reshape(obs, [1, self.agent.observation_space])
        next_obs = np.reshape(next_obs, [1, self.agent.observation_space])

        # store transition in replay memory
        self.agent.remember(obs, action, reward, next_obs, done)
        # implement experience replay
        self.agent.experience_replay()

# %%
# get params for shaping DQN architecture
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n

#initialize DQN trainer
DQN_trainer = DQN_Trainer(
                    agent = DQN_agent(observation_space, action_space), 
                    gamma = GAMMA,
                    learning_rate = LEARNING_RATE, 
                    epsilon = EXPLORATION_MAX, 
                    epsilon_decay = EXPLORATION_DECAY,
                    max_step = MAX_STEP)

#start time
DQN_start = time.time()
# train DQN for 1000 episodes
DQN_trainer.train(env, episode_count=1000, render=False)
# end time
DQN_end = time.time()

DQN_time = DQN_end - DQN_start
# Out:
# Ep: 0| Reward: 14 | Epsilon: 0.99
# Ep: 1| Reward: 23 | Epsilon: 0.99
# Ep: 2| Reward: 14 | Epsilon: 0.99
# Ep: 3| Reward: 19 | Epsilon: 0.98
# Ep: 4| Reward: 20 | Epsilon: 0.98
# Ep: 5| Reward: 23 | Epsilon: 0.97
# Ep: 6| Reward: 13 | Epsilon: 0.97
# Ep: 7| Reward: 17 | Epsilon: 0.96
# Ep: 8| Reward: 20 | Epsilon: 0.96
# Ep: 9| Reward: 25 | Epsilon: 0.95
# Ep: 10| Reward: 24 | Epsilon: 0.95
# Ep: 11| Reward: 15 | Epsilon: 0.94
# Ep: 12| Reward: 14 | Epsilon: 0.94
# Ep: 13| Reward: 14 | Epsilon: 0.93
# Ep: 14| Reward: 16 | Epsilon: 0.93
# Ep: 15| Reward: 29 | Epsilon: 0.92
# Ep: 16| Reward: 32 | Epsilon: 0.92
# Ep: 17| Reward: 40 | Epsilon: 0.91
# Ep: 18| Reward: 18 | Epsilon: 0.91
# Ep: 19| Reward: 21 | Epsilon: 0.9
# Ep: 20| Reward: 48 | Epsilon: 0.9
# Ep: 21| Reward: 21 | Epsilon: 0.9
# Ep: 22| Reward: 46 | Epsilon: 0.89
# Ep: 23| Reward: 20 | Epsilon: 0.89
# Ep: 24| Reward: 30 | Epsilon: 0.88
# Ep: 25| Reward: 19 | Epsilon: 0.88
# Ep: 26| Reward: 21 | Epsilon: 0.87
# Ep: 27| Reward: 38 | Epsilon: 0.87
# Ep: 28| Reward: 17 | Epsilon: 0.86
# Ep: 29| Reward: 42 | Epsilon: 0.86
# Ep: 30| Reward: 28 | Epsilon: 0.86
# Ep: 31| Reward: 23 | Epsilon: 0.85
# Ep: 32| Reward: 18 | Epsilon: 0.85
# Ep: 33| Reward: 29 | Epsilon: 0.84
# Ep: 34| Reward: 11 | Epsilon: 0.84
# Ep: 35| Reward: 21 | Epsilon: 0.83
# Ep: 36| Reward: 18 | Epsilon: 0.83
# Ep: 37| Reward: 25 | Epsilon: 0.83
# Ep: 38| Reward: 11 | Epsilon: 0.82
# Ep: 39| Reward: 21 | Epsilon: 0.82
# Ep: 40| Reward: 62 | Epsilon: 0.81
# Ep: 41| Reward: 46 | Epsilon: 0.81
# Ep: 42| Reward: 55 | Epsilon: 0.81
# Ep: 43| Reward: 20 | Epsilon: 0.8
# Ep: 44| Reward: 25 | Epsilon: 0.8
# Ep: 45| Reward: 33 | Epsilon: 0.79
# Ep: 46| Reward: 16 | Epsilon: 0.79
# Ep: 47| Reward: 18 | Epsilon: 0.79
# Ep: 48| Reward: 22 | Epsilon: 0.78
# Ep: 49| Reward: 37 | Epsilon: 0.78
# Ep: 50| Reward: 28 | Epsilon: 0.77
# Ep: 51| Reward: 27 | Epsilon: 0.77
# Ep: 52| Reward: 21 | Epsilon: 0.77
# Ep: 53| Reward: 52 | Epsilon: 0.76
# Ep: 54| Reward: 27 | Epsilon: 0.76
# Ep: 55| Reward: 44 | Epsilon: 0.76
# Ep: 56| Reward: 133 | Epsilon: 0.75
# Ep: 57| Reward: 78 | Epsilon: 0.75
# Ep: 58| Reward: 24 | Epsilon: 0.74
# Ep: 59| Reward: 16 | Epsilon: 0.74
# Ep: 60| Reward: 45 | Epsilon: 0.74
# Ep: 61| Reward: 45 | Epsilon: 0.73
# Ep: 62| Reward: 52 | Epsilon: 0.73
# Ep: 63| Reward: 112 | Epsilon: 0.73
# Ep: 64| Reward: 25 | Epsilon: 0.72
# Ep: 65| Reward: 55 | Epsilon: 0.72
# Ep: 66| Reward: 69 | Epsilon: 0.71
# Ep: 67| Reward: 19 | Epsilon: 0.71
# Ep: 68| Reward: 125 | Epsilon: 0.71
# Ep: 69| Reward: 15 | Epsilon: 0.7
# Ep: 70| Reward: 42 | Epsilon: 0.7
# Ep: 71| Reward: 103 | Epsilon: 0.7
# Ep: 72| Reward: 43 | Epsilon: 0.69
# Ep: 73| Reward: 28 | Epsilon: 0.69
# Ep: 74| Reward: 70 | Epsilon: 0.69
# Ep: 75| Reward: 35 | Epsilon: 0.68
# Ep: 76| Reward: 46 | Epsilon: 0.68
# Ep: 77| Reward: 68 | Epsilon: 0.68
# Ep: 78| Reward: 69 | Epsilon: 0.67
# Ep: 79| Reward: 128 | Epsilon: 0.67
# Ep: 80| Reward: 84 | Epsilon: 0.67
# Ep: 81| Reward: 95 | Epsilon: 0.66
# Ep: 82| Reward: 66 | Epsilon: 0.66
# Ep: 83| Reward: 36 | Epsilon: 0.66
# Ep: 84| Reward: 87 | Epsilon: 0.65
# Ep: 85| Reward: 200 | Epsilon: 0.65
# Ep: 86| Reward: 83 | Epsilon: 0.65
# Ep: 87| Reward: 143 | Epsilon: 0.64
# Ep: 88| Reward: 43 | Epsilon: 0.64
# Ep: 89| Reward: 63 | Epsilon: 0.64
# Ep: 90| Reward: 33 | Epsilon: 0.63
# Ep: 91| Reward: 109 | Epsilon: 0.63
# Ep: 92| Reward: 83 | Epsilon: 0.63
# Ep: 93| Reward: 69 | Epsilon: 0.62
# Ep: 94| Reward: 35 | Epsilon: 0.62
# Ep: 95| Reward: 20 | Epsilon: 0.62
# Ep: 96| Reward: 113 | Epsilon: 0.61
# Ep: 97| Reward: 67 | Epsilon: 0.61
# Ep: 98| Reward: 72 | Epsilon: 0.61
# Ep: 99| Reward: 13 | Epsilon: 0.61
# Ep: 100| Reward: 17 | Epsilon: 0.6
# Ep: 101| Reward: 64 | Epsilon: 0.6
# Ep: 102| Reward: 97 | Epsilon: 0.6
# Ep: 103| Reward: 34 | Epsilon: 0.59
# Ep: 104| Reward: 112 | Epsilon: 0.59
# Ep: 105| Reward: 34 | Epsilon: 0.59
# Ep: 106| Reward: 34 | Epsilon: 0.58
# Ep: 107| Reward: 90 | Epsilon: 0.58
# Ep: 108| Reward: 79 | Epsilon: 0.58
# Ep: 109| Reward: 153 | Epsilon: 0.58
# Ep: 110| Reward: 106 | Epsilon: 0.57
# Ep: 111| Reward: 27 | Epsilon: 0.57
# Ep: 112| Reward: 138 | Epsilon: 0.57
# Ep: 113| Reward: 71 | Epsilon: 0.56
# Ep: 114| Reward: 64 | Epsilon: 0.56
# Ep: 115| Reward: 141 | Epsilon: 0.56
# Ep: 116| Reward: 21 | Epsilon: 0.56
# Ep: 117| Reward: 17 | Epsilon: 0.55
# Ep: 118| Reward: 112 | Epsilon: 0.55
# Ep: 119| Reward: 100 | Epsilon: 0.55
# Ep: 120| Reward: 78 | Epsilon: 0.55
# Ep: 121| Reward: 31 | Epsilon: 0.54
# Ep: 122| Reward: 90 | Epsilon: 0.54
# Ep: 123| Reward: 57 | Epsilon: 0.54
# Ep: 124| Reward: 93 | Epsilon: 0.53
# Ep: 125| Reward: 54 | Epsilon: 0.53
# Ep: 126| Reward: 58 | Epsilon: 0.53
# Ep: 127| Reward: 26 | Epsilon: 0.53
# Ep: 128| Reward: 50 | Epsilon: 0.52
# Ep: 129| Reward: 21 | Epsilon: 0.52
# Ep: 130| Reward: 93 | Epsilon: 0.52
# Ep: 131| Reward: 14 | Epsilon: 0.52
# Ep: 132| Reward: 126 | Epsilon: 0.51
# Ep: 133| Reward: 40 | Epsilon: 0.51
# Ep: 134| Reward: 41 | Epsilon: 0.51
# Ep: 135| Reward: 27 | Epsilon: 0.51
# Ep: 136| Reward: 20 | Epsilon: 0.5
# Ep: 137| Reward: 139 | Epsilon: 0.5
# Ep: 138| Reward: 40 | Epsilon: 0.5
# Ep: 139| Reward: 80 | Epsilon: 0.5
# Ep: 140| Reward: 26 | Epsilon: 0.49
# Ep: 141| Reward: 45 | Epsilon: 0.49
# Ep: 142| Reward: 70 | Epsilon: 0.49
# Ep: 143| Reward: 108 | Epsilon: 0.49
# Ep: 144| Reward: 140 | Epsilon: 0.48
# Ep: 145| Reward: 61 | Epsilon: 0.48
# Ep: 146| Reward: 17 | Epsilon: 0.48
# Ep: 147| Reward: 128 | Epsilon: 0.48
# Ep: 148| Reward: 93 | Epsilon: 0.47
# Ep: 149| Reward: 17 | Epsilon: 0.47
# Ep: 150| Reward: 45 | Epsilon: 0.47
# Ep: 151| Reward: 93 | Epsilon: 0.47
# Ep: 152| Reward: 76 | Epsilon: 0.46
# Ep: 153| Reward: 69 | Epsilon: 0.46
# Ep: 154| Reward: 50 | Epsilon: 0.46
# Ep: 155| Reward: 17 | Epsilon: 0.46
# Ep: 156| Reward: 84 | Epsilon: 0.46
# Ep: 157| Reward: 40 | Epsilon: 0.45
# Ep: 158| Reward: 19 | Epsilon: 0.45
# Ep: 159| Reward: 13 | Epsilon: 0.45
# Ep: 160| Reward: 132 | Epsilon: 0.45
# Ep: 161| Reward: 107 | Epsilon: 0.44
# Ep: 162| Reward: 16 | Epsilon: 0.44
# Ep: 163| Reward: 161 | Epsilon: 0.44
# Ep: 164| Reward: 48 | Epsilon: 0.44
# Ep: 165| Reward: 191 | Epsilon: 0.44
# Ep: 166| Reward: 18 | Epsilon: 0.43
# Ep: 167| Reward: 55 | Epsilon: 0.43
# Ep: 168| Reward: 104 | Epsilon: 0.43
# Ep: 169| Reward: 94 | Epsilon: 0.43
# Ep: 170| Reward: 17 | Epsilon: 0.42
# Ep: 171| Reward: 17 | Epsilon: 0.42
# Ep: 172| Reward: 41 | Epsilon: 0.42
# Ep: 173| Reward: 86 | Epsilon: 0.42
# Ep: 174| Reward: 43 | Epsilon: 0.42
# Ep: 175| Reward: 21 | Epsilon: 0.41
# Ep: 176| Reward: 54 | Epsilon: 0.41
# Ep: 177| Reward: 46 | Epsilon: 0.41
# Ep: 178| Reward: 124 | Epsilon: 0.41
# Ep: 179| Reward: 95 | Epsilon: 0.41
# Ep: 180| Reward: 93 | Epsilon: 0.4
# Ep: 181| Reward: 146 | Epsilon: 0.4
# Ep: 182| Reward: 14 | Epsilon: 0.4
# Ep: 183| Reward: 21 | Epsilon: 0.4
# Ep: 184| Reward: 106 | Epsilon: 0.4
# Ep: 185| Reward: 105 | Epsilon: 0.39
# Ep: 186| Reward: 78 | Epsilon: 0.39
# Ep: 187| Reward: 38 | Epsilon: 0.39
# Ep: 188| Reward: 12 | Epsilon: 0.39
# Ep: 189| Reward: 26 | Epsilon: 0.39
# Ep: 190| Reward: 85 | Epsilon: 0.38
# Ep: 191| Reward: 50 | Epsilon: 0.38
# Ep: 192| Reward: 40 | Epsilon: 0.38
# Ep: 193| Reward: 141 | Epsilon: 0.38
# Ep: 194| Reward: 83 | Epsilon: 0.38
# Ep: 195| Reward: 116 | Epsilon: 0.37
# Ep: 196| Reward: 55 | Epsilon: 0.37
# Ep: 197| Reward: 147 | Epsilon: 0.37
# Ep: 198| Reward: 100 | Epsilon: 0.37
# Ep: 199| Reward: 66 | Epsilon: 0.37
# Ep: 200| Reward: 179 | Epsilon: 0.37
# Ep: 201| Reward: 25 | Epsilon: 0.36
# Ep: 202| Reward: 96 | Epsilon: 0.36
# Ep: 203| Reward: 13 | Epsilon: 0.36
# Ep: 204| Reward: 128 | Epsilon: 0.36
# Ep: 205| Reward: 200 | Epsilon: 0.36
# Ep: 206| Reward: 98 | Epsilon: 0.35
# Ep: 207| Reward: 36 | Epsilon: 0.35
# Ep: 208| Reward: 135 | Epsilon: 0.35
# Ep: 209| Reward: 33 | Epsilon: 0.35
# Ep: 210| Reward: 66 | Epsilon: 0.35
# Ep: 211| Reward: 24 | Epsilon: 0.35
# Ep: 212| Reward: 35 | Epsilon: 0.34
# Ep: 213| Reward: 101 | Epsilon: 0.34
# Ep: 214| Reward: 13 | Epsilon: 0.34
# Ep: 215| Reward: 24 | Epsilon: 0.34
# Ep: 216| Reward: 132 | Epsilon: 0.34
# Ep: 217| Reward: 108 | Epsilon: 0.34
# Ep: 218| Reward: 140 | Epsilon: 0.33
# Ep: 219| Reward: 79 | Epsilon: 0.33
# Ep: 220| Reward: 125 | Epsilon: 0.33
# Ep: 221| Reward: 89 | Epsilon: 0.33
# Ep: 222| Reward: 101 | Epsilon: 0.33
# Ep: 223| Reward: 95 | Epsilon: 0.33
# Ep: 224| Reward: 24 | Epsilon: 0.32
# Ep: 225| Reward: 145 | Epsilon: 0.32
# Ep: 226| Reward: 200 | Epsilon: 0.32
# Ep: 227| Reward: 148 | Epsilon: 0.32
# Ep: 228| Reward: 129 | Epsilon: 0.32
# Ep: 229| Reward: 43 | Epsilon: 0.32
# Ep: 230| Reward: 67 | Epsilon: 0.31
# Ep: 231| Reward: 88 | Epsilon: 0.31
# Ep: 232| Reward: 27 | Epsilon: 0.31
# Ep: 233| Reward: 69 | Epsilon: 0.31
# Ep: 234| Reward: 200 | Epsilon: 0.31
# Ep: 235| Reward: 29 | Epsilon: 0.31
# Ep: 236| Reward: 16 | Epsilon: 0.3
# Ep: 237| Reward: 53 | Epsilon: 0.3
# Ep: 238| Reward: 39 | Epsilon: 0.3
# Ep: 239| Reward: 191 | Epsilon: 0.3
# Ep: 240| Reward: 154 | Epsilon: 0.3
# Ep: 241| Reward: 136 | Epsilon: 0.3
# Ep: 242| Reward: 22 | Epsilon: 0.3
# Ep: 243| Reward: 200 | Epsilon: 0.29
# Ep: 244| Reward: 200 | Epsilon: 0.29
# Ep: 245| Reward: 48 | Epsilon: 0.29
# Ep: 246| Reward: 44 | Epsilon: 0.29
# Ep: 247| Reward: 13 | Epsilon: 0.29
# Ep: 248| Reward: 27 | Epsilon: 0.29
# Ep: 249| Reward: 11 | Epsilon: 0.29
# Ep: 250| Reward: 118 | Epsilon: 0.28
# Ep: 251| Reward: 200 | Epsilon: 0.28
# Ep: 252| Reward: 23 | Epsilon: 0.28
# Ep: 253| Reward: 200 | Epsilon: 0.28
# Ep: 254| Reward: 200 | Epsilon: 0.28
# Ep: 255| Reward: 200 | Epsilon: 0.28
# Ep: 256| Reward: 200 | Epsilon: 0.28
# Ep: 257| Reward: 40 | Epsilon: 0.27
# Ep: 258| Reward: 24 | Epsilon: 0.27
# Ep: 259| Reward: 200 | Epsilon: 0.27
# Ep: 260| Reward: 74 | Epsilon: 0.27
# Ep: 261| Reward: 99 | Epsilon: 0.27
# Ep: 262| Reward: 46 | Epsilon: 0.27
# Ep: 263| Reward: 134 | Epsilon: 0.27
# Ep: 264| Reward: 137 | Epsilon: 0.26
# Ep: 265| Reward: 35 | Epsilon: 0.26
# Ep: 266| Reward: 137 | Epsilon: 0.26
# Ep: 267| Reward: 200 | Epsilon: 0.26
# Ep: 268| Reward: 39 | Epsilon: 0.26
# Ep: 269| Reward: 60 | Epsilon: 0.26
# Ep: 270| Reward: 200 | Epsilon: 0.26
# Ep: 271| Reward: 117 | Epsilon: 0.26
# Ep: 272| Reward: 90 | Epsilon: 0.25
# Ep: 273| Reward: 200 | Epsilon: 0.25
# Ep: 274| Reward: 139 | Epsilon: 0.25
# Ep: 275| Reward: 154 | Epsilon: 0.25
# Ep: 276| Reward: 200 | Epsilon: 0.25
# Ep: 277| Reward: 178 | Epsilon: 0.25
# Ep: 278| Reward: 121 | Epsilon: 0.25
# Ep: 279| Reward: 200 | Epsilon: 0.25
# Ep: 280| Reward: 71 | Epsilon: 0.24
# Ep: 281| Reward: 166 | Epsilon: 0.24
# Ep: 282| Reward: 200 | Epsilon: 0.24
# Ep: 283| Reward: 118 | Epsilon: 0.24
# Ep: 284| Reward: 167 | Epsilon: 0.24
# Ep: 285| Reward: 107 | Epsilon: 0.24
# Ep: 286| Reward: 35 | Epsilon: 0.24
# Ep: 287| Reward: 31 | Epsilon: 0.24
# Ep: 288| Reward: 123 | Epsilon: 0.23
# Ep: 289| Reward: 88 | Epsilon: 0.23
# Ep: 290| Reward: 113 | Epsilon: 0.23
# Ep: 291| Reward: 15 | Epsilon: 0.23
# Ep: 292| Reward: 97 | Epsilon: 0.23
# Ep: 293| Reward: 184 | Epsilon: 0.23
# Ep: 294| Reward: 164 | Epsilon: 0.23
# Ep: 295| Reward: 160 | Epsilon: 0.23
# Ep: 296| Reward: 200 | Epsilon: 0.23
# Ep: 297| Reward: 13 | Epsilon: 0.22
# Ep: 298| Reward: 132 | Epsilon: 0.22
# Ep: 299| Reward: 101 | Epsilon: 0.22
# Ep: 300| Reward: 200 | Epsilon: 0.22
# Ep: 301| Reward: 136 | Epsilon: 0.22
# Ep: 302| Reward: 200 | Epsilon: 0.22
# Ep: 303| Reward: 57 | Epsilon: 0.22
# Ep: 304| Reward: 99 | Epsilon: 0.22
# Ep: 305| Reward: 102 | Epsilon: 0.22
# Ep: 306| Reward: 132 | Epsilon: 0.21
# Ep: 307| Reward: 36 | Epsilon: 0.21
# Ep: 308| Reward: 14 | Epsilon: 0.21
# Ep: 309| Reward: 26 | Epsilon: 0.21
# Ep: 310| Reward: 60 | Epsilon: 0.21
# Ep: 311| Reward: 44 | Epsilon: 0.21
# Ep: 312| Reward: 34 | Epsilon: 0.21
# Ep: 313| Reward: 37 | Epsilon: 0.21
# Ep: 314| Reward: 100 | Epsilon: 0.21
# Ep: 315| Reward: 13 | Epsilon: 0.21
# Ep: 316| Reward: 45 | Epsilon: 0.2
# Ep: 317| Reward: 107 | Epsilon: 0.2
# Ep: 318| Reward: 158 | Epsilon: 0.2
# Ep: 319| Reward: 17 | Epsilon: 0.2
# Ep: 320| Reward: 20 | Epsilon: 0.2
# Ep: 321| Reward: 136 | Epsilon: 0.2
# Ep: 322| Reward: 139 | Epsilon: 0.2
# Ep: 323| Reward: 109 | Epsilon: 0.2
# Ep: 324| Reward: 141 | Epsilon: 0.2
# Ep: 325| Reward: 68 | Epsilon: 0.2
# Ep: 326| Reward: 104 | Epsilon: 0.19
# Ep: 327| Reward: 91 | Epsilon: 0.19
# Ep: 328| Reward: 56 | Epsilon: 0.19
# Ep: 329| Reward: 56 | Epsilon: 0.19
# Ep: 330| Reward: 69 | Epsilon: 0.19
# Ep: 331| Reward: 148 | Epsilon: 0.19
# Ep: 332| Reward: 138 | Epsilon: 0.19
# Ep: 333| Reward: 37 | Epsilon: 0.19
# Ep: 334| Reward: 133 | Epsilon: 0.19
# Ep: 335| Reward: 43 | Epsilon: 0.19
# Ep: 336| Reward: 89 | Epsilon: 0.18
# Ep: 337| Reward: 134 | Epsilon: 0.18
# Ep: 338| Reward: 14 | Epsilon: 0.18
# Ep: 339| Reward: 125 | Epsilon: 0.18
# Ep: 340| Reward: 176 | Epsilon: 0.18
# Ep: 341| Reward: 164 | Epsilon: 0.18
# Ep: 342| Reward: 119 | Epsilon: 0.18
# Ep: 343| Reward: 128 | Epsilon: 0.18
# Ep: 344| Reward: 152 | Epsilon: 0.18
# Ep: 345| Reward: 23 | Epsilon: 0.18
# Ep: 346| Reward: 173 | Epsilon: 0.18
# Ep: 347| Reward: 42 | Epsilon: 0.17
# Ep: 348| Reward: 60 | Epsilon: 0.17
# Ep: 349| Reward: 31 | Epsilon: 0.17
# Ep: 350| Reward: 27 | Epsilon: 0.17
# Ep: 351| Reward: 138 | Epsilon: 0.17
# Ep: 352| Reward: 126 | Epsilon: 0.17
# Ep: 353| Reward: 92 | Epsilon: 0.17
# Ep: 354| Reward: 17 | Epsilon: 0.17
# Ep: 355| Reward: 38 | Epsilon: 0.17
# Ep: 356| Reward: 181 | Epsilon: 0.17
# Ep: 357| Reward: 200 | Epsilon: 0.17
# Ep: 358| Reward: 200 | Epsilon: 0.17
# Ep: 359| Reward: 200 | Epsilon: 0.16
# Ep: 360| Reward: 142 | Epsilon: 0.16
# Ep: 361| Reward: 200 | Epsilon: 0.16
# Ep: 362| Reward: 160 | Epsilon: 0.16
# Ep: 363| Reward: 200 | Epsilon: 0.16
# Ep: 364| Reward: 14 | Epsilon: 0.16
# Ep: 365| Reward: 143 | Epsilon: 0.16
# Ep: 366| Reward: 16 | Epsilon: 0.16
# Ep: 367| Reward: 200 | Epsilon: 0.16
# Ep: 368| Reward: 114 | Epsilon: 0.16
# Ep: 369| Reward: 19 | Epsilon: 0.16
# Ep: 370| Reward: 14 | Epsilon: 0.16
# Ep: 371| Reward: 177 | Epsilon: 0.15
# Ep: 372| Reward: 28 | Epsilon: 0.15
# Ep: 373| Reward: 153 | Epsilon: 0.15
# Ep: 374| Reward: 47 | Epsilon: 0.15
# Ep: 375| Reward: 97 | Epsilon: 0.15
# Ep: 376| Reward: 49 | Epsilon: 0.15
# Ep: 377| Reward: 11 | Epsilon: 0.15
# Ep: 378| Reward: 44 | Epsilon: 0.15
# Ep: 379| Reward: 149 | Epsilon: 0.15
# Ep: 380| Reward: 200 | Epsilon: 0.15
# Ep: 381| Reward: 161 | Epsilon: 0.15
# Ep: 382| Reward: 200 | Epsilon: 0.15
# Ep: 383| Reward: 90 | Epsilon: 0.15
# Ep: 384| Reward: 101 | Epsilon: 0.15
# Ep: 385| Reward: 168 | Epsilon: 0.14
# Ep: 386| Reward: 132 | Epsilon: 0.14
# Ep: 387| Reward: 200 | Epsilon: 0.14
# Ep: 388| Reward: 121 | Epsilon: 0.14
# Ep: 389| Reward: 26 | Epsilon: 0.14
# Ep: 390| Reward: 200 | Epsilon: 0.14
# Ep: 391| Reward: 13 | Epsilon: 0.14
# Ep: 392| Reward: 200 | Epsilon: 0.14
# Ep: 393| Reward: 148 | Epsilon: 0.14
# Ep: 394| Reward: 184 | Epsilon: 0.14
# Ep: 395| Reward: 72 | Epsilon: 0.14
# Ep: 396| Reward: 131 | Epsilon: 0.14
# Ep: 397| Reward: 80 | Epsilon: 0.14
# Ep: 398| Reward: 182 | Epsilon: 0.14
# Ep: 399| Reward: 168 | Epsilon: 0.13
# Ep: 400| Reward: 164 | Epsilon: 0.13
# Ep: 401| Reward: 36 | Epsilon: 0.13
# Ep: 402| Reward: 86 | Epsilon: 0.13
# Ep: 403| Reward: 103 | Epsilon: 0.13
# Ep: 404| Reward: 168 | Epsilon: 0.13
# Ep: 405| Reward: 74 | Epsilon: 0.13
# Ep: 406| Reward: 66 | Epsilon: 0.13
# Ep: 407| Reward: 200 | Epsilon: 0.13
# Ep: 408| Reward: 200 | Epsilon: 0.13
# Ep: 409| Reward: 151 | Epsilon: 0.13
# Ep: 410| Reward: 200 | Epsilon: 0.13
# Ep: 411| Reward: 141 | Epsilon: 0.13
# Ep: 412| Reward: 90 | Epsilon: 0.13
# Ep: 413| Reward: 122 | Epsilon: 0.13
# Ep: 414| Reward: 70 | Epsilon: 0.12
# Ep: 415| Reward: 138 | Epsilon: 0.12
# Ep: 416| Reward: 91 | Epsilon: 0.12
# Ep: 417| Reward: 127 | Epsilon: 0.12
# Ep: 418| Reward: 83 | Epsilon: 0.12
# Ep: 419| Reward: 14 | Epsilon: 0.12
# Ep: 420| Reward: 143 | Epsilon: 0.12
# Ep: 421| Reward: 92 | Epsilon: 0.12
# Ep: 422| Reward: 139 | Epsilon: 0.12
# Ep: 423| Reward: 87 | Epsilon: 0.12
# Ep: 424| Reward: 200 | Epsilon: 0.12
# Ep: 425| Reward: 144 | Epsilon: 0.12
# Ep: 426| Reward: 149 | Epsilon: 0.12
# Ep: 427| Reward: 157 | Epsilon: 0.12
# Ep: 428| Reward: 126 | Epsilon: 0.12
# Ep: 429| Reward: 120 | Epsilon: 0.12
# Ep: 430| Reward: 53 | Epsilon: 0.12
# Ep: 431| Reward: 200 | Epsilon: 0.11
# Ep: 432| Reward: 125 | Epsilon: 0.11
# Ep: 433| Reward: 17 | Epsilon: 0.11
# Ep: 434| Reward: 130 | Epsilon: 0.11
# Ep: 435| Reward: 200 | Epsilon: 0.11
# Ep: 436| Reward: 106 | Epsilon: 0.11
# Ep: 437| Reward: 35 | Epsilon: 0.11
# Ep: 438| Reward: 124 | Epsilon: 0.11
# Ep: 439| Reward: 12 | Epsilon: 0.11
# Ep: 440| Reward: 118 | Epsilon: 0.11
# Ep: 441| Reward: 68 | Epsilon: 0.11
# Ep: 442| Reward: 200 | Epsilon: 0.11
# Ep: 443| Reward: 127 | Epsilon: 0.11
# Ep: 444| Reward: 22 | Epsilon: 0.11
# Ep: 445| Reward: 48 | Epsilon: 0.11
# Ep: 446| Reward: 136 | Epsilon: 0.11
# Ep: 447| Reward: 134 | Epsilon: 0.11
# Ep: 448| Reward: 183 | Epsilon: 0.11
# Ep: 449| Reward: 159 | Epsilon: 0.1
# Ep: 450| Reward: 168 | Epsilon: 0.1
# Ep: 451| Reward: 101 | Epsilon: 0.1
# Ep: 452| Reward: 156 | Epsilon: 0.1
# Ep: 453| Reward: 111 | Epsilon: 0.1
# Ep: 454| Reward: 63 | Epsilon: 0.1
# Ep: 455| Reward: 23 | Epsilon: 0.1
# Ep: 456| Reward: 116 | Epsilon: 0.1
# Ep: 457| Reward: 113 | Epsilon: 0.1
# Ep: 458| Reward: 132 | Epsilon: 0.1
# Ep: 459| Reward: 166 | Epsilon: 0.1
# Ep: 460| Reward: 163 | Epsilon: 0.1
# Ep: 461| Reward: 153 | Epsilon: 0.1
# Ep: 462| Reward: 127 | Epsilon: 0.1
# Ep: 463| Reward: 132 | Epsilon: 0.1
# Ep: 464| Reward: 65 | Epsilon: 0.1
# Ep: 465| Reward: 111 | Epsilon: 0.1
# Ep: 466| Reward: 49 | Epsilon: 0.1
# Ep: 467| Reward: 117 | Epsilon: 0.1
# Ep: 468| Reward: 84 | Epsilon: 0.1
# Ep: 469| Reward: 34 | Epsilon: 0.09
# Ep: 470| Reward: 99 | Epsilon: 0.09
# Ep: 471| Reward: 74 | Epsilon: 0.09
# Ep: 472| Reward: 200 | Epsilon: 0.09
# Ep: 473| Reward: 200 | Epsilon: 0.09
# Ep: 474| Reward: 167 | Epsilon: 0.09
# Ep: 475| Reward: 34 | Epsilon: 0.09
# Ep: 476| Reward: 141 | Epsilon: 0.09
# Ep: 477| Reward: 112 | Epsilon: 0.09
# Ep: 478| Reward: 200 | Epsilon: 0.09
# Ep: 479| Reward: 29 | Epsilon: 0.09
# Ep: 480| Reward: 200 | Epsilon: 0.09
# Ep: 481| Reward: 48 | Epsilon: 0.09
# Ep: 482| Reward: 18 | Epsilon: 0.09
# Ep: 483| Reward: 200 | Epsilon: 0.09
# Ep: 484| Reward: 103 | Epsilon: 0.09
# Ep: 485| Reward: 131 | Epsilon: 0.09
# Ep: 486| Reward: 158 | Epsilon: 0.09
# Ep: 487| Reward: 44 | Epsilon: 0.09
# Ep: 488| Reward: 200 | Epsilon: 0.09
# Ep: 489| Reward: 89 | Epsilon: 0.09
# Ep: 490| Reward: 29 | Epsilon: 0.09
# Ep: 491| Reward: 72 | Epsilon: 0.08
# Ep: 492| Reward: 74 | Epsilon: 0.08
# Ep: 493| Reward: 200 | Epsilon: 0.08
# Ep: 494| Reward: 55 | Epsilon: 0.08
# Ep: 495| Reward: 96 | Epsilon: 0.08
# Ep: 496| Reward: 129 | Epsilon: 0.08
# Ep: 497| Reward: 55 | Epsilon: 0.08
# Ep: 498| Reward: 26 | Epsilon: 0.08
# Ep: 499| Reward: 39 | Epsilon: 0.08
# Ep: 500| Reward: 81 | Epsilon: 0.08
# Ep: 501| Reward: 132 | Epsilon: 0.08
# Ep: 502| Reward: 200 | Epsilon: 0.08
# Ep: 503| Reward: 84 | Epsilon: 0.08
# Ep: 504| Reward: 63 | Epsilon: 0.08
# Ep: 505| Reward: 33 | Epsilon: 0.08
# Ep: 506| Reward: 61 | Epsilon: 0.08
# Ep: 507| Reward: 126 | Epsilon: 0.08
# Ep: 508| Reward: 140 | Epsilon: 0.08
# Ep: 509| Reward: 174 | Epsilon: 0.08
# Ep: 510| Reward: 124 | Epsilon: 0.08
# Ep: 511| Reward: 150 | Epsilon: 0.08
# Ep: 512| Reward: 168 | Epsilon: 0.08
# Ep: 513| Reward: 110 | Epsilon: 0.08
# Ep: 514| Reward: 117 | Epsilon: 0.08
# Ep: 515| Reward: 21 | Epsilon: 0.08
# Ep: 516| Reward: 130 | Epsilon: 0.07
# Ep: 517| Reward: 185 | Epsilon: 0.07
# Ep: 518| Reward: 167 | Epsilon: 0.07
# Ep: 519| Reward: 186 | Epsilon: 0.07
# Ep: 520| Reward: 19 | Epsilon: 0.07
# Ep: 521| Reward: 135 | Epsilon: 0.07
# Ep: 522| Reward: 114 | Epsilon: 0.07
# Ep: 523| Reward: 200 | Epsilon: 0.07
# Ep: 524| Reward: 166 | Epsilon: 0.07
# Ep: 525| Reward: 56 | Epsilon: 0.07
# Ep: 526| Reward: 200 | Epsilon: 0.07
# Ep: 527| Reward: 200 | Epsilon: 0.07
# Ep: 528| Reward: 102 | Epsilon: 0.07
# Ep: 529| Reward: 133 | Epsilon: 0.07
# Ep: 530| Reward: 200 | Epsilon: 0.07
# Ep: 531| Reward: 95 | Epsilon: 0.07
# Ep: 532| Reward: 200 | Epsilon: 0.07
# Ep: 533| Reward: 200 | Epsilon: 0.07
# Ep: 534| Reward: 200 | Epsilon: 0.07
# Ep: 535| Reward: 11 | Epsilon: 0.07
# Ep: 536| Reward: 10 | Epsilon: 0.07
# Ep: 537| Reward: 105 | Epsilon: 0.07
# Ep: 538| Reward: 121 | Epsilon: 0.07
# Ep: 539| Reward: 154 | Epsilon: 0.07
# Ep: 540| Reward: 89 | Epsilon: 0.07
# Ep: 541| Reward: 106 | Epsilon: 0.07
# Ep: 542| Reward: 89 | Epsilon: 0.07
# Ep: 543| Reward: 107 | Epsilon: 0.07
# Ep: 544| Reward: 117 | Epsilon: 0.07
# Ep: 545| Reward: 128 | Epsilon: 0.06
# Ep: 546| Reward: 200 | Epsilon: 0.06
# Ep: 547| Reward: 133 | Epsilon: 0.06
# Ep: 548| Reward: 108 | Epsilon: 0.06
# Ep: 549| Reward: 66 | Epsilon: 0.06
# Ep: 550| Reward: 119 | Epsilon: 0.06
# Ep: 551| Reward: 142 | Epsilon: 0.06
# Ep: 552| Reward: 92 | Epsilon: 0.06
# Ep: 553| Reward: 106 | Epsilon: 0.06
# Ep: 554| Reward: 129 | Epsilon: 0.06
# Ep: 555| Reward: 95 | Epsilon: 0.06
# Ep: 556| Reward: 200 | Epsilon: 0.06
# Ep: 557| Reward: 131 | Epsilon: 0.06
# Ep: 558| Reward: 128 | Epsilon: 0.06
# Ep: 559| Reward: 102 | Epsilon: 0.06
# Ep: 560| Reward: 133 | Epsilon: 0.06
# Ep: 561| Reward: 111 | Epsilon: 0.06
# Ep: 562| Reward: 152 | Epsilon: 0.06
# Ep: 563| Reward: 110 | Epsilon: 0.06
# Ep: 564| Reward: 103 | Epsilon: 0.06
# Ep: 565| Reward: 36 | Epsilon: 0.06
# Ep: 566| Reward: 51 | Epsilon: 0.06
# Ep: 567| Reward: 93 | Epsilon: 0.06
# Ep: 568| Reward: 9 | Epsilon: 0.06
# Ep: 569| Reward: 10 | Epsilon: 0.06
# Ep: 570| Reward: 91 | Epsilon: 0.06
# Ep: 571| Reward: 121 | Epsilon: 0.06
# Ep: 572| Reward: 77 | Epsilon: 0.06
# Ep: 573| Reward: 192 | Epsilon: 0.06
# Ep: 574| Reward: 98 | Epsilon: 0.06
# Ep: 575| Reward: 74 | Epsilon: 0.06
# Ep: 576| Reward: 200 | Epsilon: 0.06
# Ep: 577| Reward: 37 | Epsilon: 0.06
# Ep: 578| Reward: 27 | Epsilon: 0.05
# Ep: 579| Reward: 91 | Epsilon: 0.05
# Ep: 580| Reward: 10 | Epsilon: 0.05
# Ep: 581| Reward: 117 | Epsilon: 0.05
# Ep: 582| Reward: 133 | Epsilon: 0.05
# Ep: 583| Reward: 104 | Epsilon: 0.05
# Ep: 584| Reward: 200 | Epsilon: 0.05
# Ep: 585| Reward: 30 | Epsilon: 0.05
# Ep: 586| Reward: 97 | Epsilon: 0.05
# Ep: 587| Reward: 22 | Epsilon: 0.05
# Ep: 588| Reward: 115 | Epsilon: 0.05
# Ep: 589| Reward: 187 | Epsilon: 0.05
# Ep: 590| Reward: 63 | Epsilon: 0.05
# Ep: 591| Reward: 161 | Epsilon: 0.05
# Ep: 592| Reward: 99 | Epsilon: 0.05
# Ep: 593| Reward: 200 | Epsilon: 0.05
# Ep: 594| Reward: 132 | Epsilon: 0.05
# Ep: 595| Reward: 80 | Epsilon: 0.05
# Ep: 596| Reward: 153 | Epsilon: 0.05
# Ep: 597| Reward: 19 | Epsilon: 0.05
# Ep: 598| Reward: 18 | Epsilon: 0.05
# Ep: 599| Reward: 26 | Epsilon: 0.05
# Ep: 600| Reward: 98 | Epsilon: 0.05
# Ep: 601| Reward: 174 | Epsilon: 0.05
# Ep: 602| Reward: 26 | Epsilon: 0.05
# Ep: 603| Reward: 14 | Epsilon: 0.05
# Ep: 604| Reward: 105 | Epsilon: 0.05
# Ep: 605| Reward: 93 | Epsilon: 0.05
# Ep: 606| Reward: 94 | Epsilon: 0.05
# Ep: 607| Reward: 68 | Epsilon: 0.05
# Ep: 608| Reward: 111 | Epsilon: 0.05
# Ep: 609| Reward: 63 | Epsilon: 0.05
# Ep: 610| Reward: 99 | Epsilon: 0.05
# Ep: 611| Reward: 131 | Epsilon: 0.05
# Ep: 612| Reward: 141 | Epsilon: 0.05
# Ep: 613| Reward: 10 | Epsilon: 0.05
# Ep: 614| Reward: 100 | Epsilon: 0.05
# Ep: 615| Reward: 123 | Epsilon: 0.05
# Ep: 616| Reward: 144 | Epsilon: 0.05
# Ep: 617| Reward: 97 | Epsilon: 0.05
# Ep: 618| Reward: 102 | Epsilon: 0.04
# Ep: 619| Reward: 106 | Epsilon: 0.04
# Ep: 620| Reward: 126 | Epsilon: 0.04
# Ep: 621| Reward: 191 | Epsilon: 0.04
# Ep: 622| Reward: 29 | Epsilon: 0.04
# Ep: 623| Reward: 95 | Epsilon: 0.04
# Ep: 624| Reward: 9 | Epsilon: 0.04
# Ep: 625| Reward: 9 | Epsilon: 0.04
# Ep: 626| Reward: 9 | Epsilon: 0.04
# Ep: 627| Reward: 10 | Epsilon: 0.04
# Ep: 628| Reward: 108 | Epsilon: 0.04
# Ep: 629| Reward: 103 | Epsilon: 0.04
# Ep: 630| Reward: 114 | Epsilon: 0.04
# Ep: 631| Reward: 45 | Epsilon: 0.04
# Ep: 632| Reward: 140 | Epsilon: 0.04
# Ep: 633| Reward: 17 | Epsilon: 0.04
# Ep: 634| Reward: 96 | Epsilon: 0.04
# Ep: 635| Reward: 118 | Epsilon: 0.04
# Ep: 636| Reward: 136 | Epsilon: 0.04
# Ep: 637| Reward: 150 | Epsilon: 0.04
# Ep: 638| Reward: 115 | Epsilon: 0.04
# Ep: 639| Reward: 110 | Epsilon: 0.04
# Ep: 640| Reward: 96 | Epsilon: 0.04
# Ep: 641| Reward: 200 | Epsilon: 0.04
# Ep: 642| Reward: 200 | Epsilon: 0.04
# Ep: 643| Reward: 200 | Epsilon: 0.04
# Ep: 644| Reward: 137 | Epsilon: 0.04
# Ep: 645| Reward: 91 | Epsilon: 0.04
# Ep: 646| Reward: 120 | Epsilon: 0.04
# Ep: 647| Reward: 85 | Epsilon: 0.04
# Ep: 648| Reward: 88 | Epsilon: 0.04
# Ep: 649| Reward: 121 | Epsilon: 0.04
# Ep: 650| Reward: 90 | Epsilon: 0.04
# Ep: 651| Reward: 132 | Epsilon: 0.04
# Ep: 652| Reward: 200 | Epsilon: 0.04
# Ep: 653| Reward: 200 | Epsilon: 0.04
# Ep: 654| Reward: 72 | Epsilon: 0.04
# Ep: 655| Reward: 176 | Epsilon: 0.04
# Ep: 656| Reward: 154 | Epsilon: 0.04
# Ep: 657| Reward: 197 | Epsilon: 0.04
# Ep: 658| Reward: 97 | Epsilon: 0.04
# Ep: 659| Reward: 121 | Epsilon: 0.04
# Ep: 660| Reward: 18 | Epsilon: 0.04
# Ep: 661| Reward: 98 | Epsilon: 0.04
# Ep: 662| Reward: 61 | Epsilon: 0.04
# Ep: 663| Reward: 160 | Epsilon: 0.04
# Ep: 664| Reward: 68 | Epsilon: 0.04
# Ep: 665| Reward: 50 | Epsilon: 0.04
# Ep: 666| Reward: 9 | Epsilon: 0.04
# Ep: 667| Reward: 93 | Epsilon: 0.04
# Ep: 668| Reward: 187 | Epsilon: 0.03
# Ep: 669| Reward: 75 | Epsilon: 0.03
# Ep: 670| Reward: 121 | Epsilon: 0.03
# Ep: 671| Reward: 115 | Epsilon: 0.03
# Ep: 672| Reward: 101 | Epsilon: 0.03
# Ep: 673| Reward: 100 | Epsilon: 0.03
# Ep: 674| Reward: 200 | Epsilon: 0.03
# Ep: 675| Reward: 118 | Epsilon: 0.03
# Ep: 676| Reward: 10 | Epsilon: 0.03
# Ep: 677| Reward: 89 | Epsilon: 0.03
# Ep: 678| Reward: 147 | Epsilon: 0.03
# Ep: 679| Reward: 129 | Epsilon: 0.03
# Ep: 680| Reward: 177 | Epsilon: 0.03
# Ep: 681| Reward: 115 | Epsilon: 0.03
# Ep: 682| Reward: 200 | Epsilon: 0.03
# Ep: 683| Reward: 200 | Epsilon: 0.03
# Ep: 684| Reward: 200 | Epsilon: 0.03
# Ep: 685| Reward: 96 | Epsilon: 0.03
# Ep: 686| Reward: 130 | Epsilon: 0.03
# Ep: 687| Reward: 77 | Epsilon: 0.03
# Ep: 688| Reward: 200 | Epsilon: 0.03
# Ep: 689| Reward: 154 | Epsilon: 0.03
# Ep: 690| Reward: 200 | Epsilon: 0.03
# Ep: 691| Reward: 104 | Epsilon: 0.03
# Ep: 692| Reward: 120 | Epsilon: 0.03
# Ep: 693| Reward: 121 | Epsilon: 0.03
# Ep: 694| Reward: 200 | Epsilon: 0.03
# Ep: 695| Reward: 55 | Epsilon: 0.03
# Ep: 696| Reward: 200 | Epsilon: 0.03
# Ep: 697| Reward: 200 | Epsilon: 0.03
# Ep: 698| Reward: 139 | Epsilon: 0.03
# Ep: 699| Reward: 185 | Epsilon: 0.03
# Ep: 700| Reward: 178 | Epsilon: 0.03
# Ep: 701| Reward: 114 | Epsilon: 0.03
# Ep: 702| Reward: 146 | Epsilon: 0.03
# Ep: 703| Reward: 55 | Epsilon: 0.03
# Ep: 704| Reward: 200 | Epsilon: 0.03
# Ep: 705| Reward: 173 | Epsilon: 0.03
# Ep: 706| Reward: 139 | Epsilon: 0.03
# Ep: 707| Reward: 93 | Epsilon: 0.03
# Ep: 708| Reward: 200 | Epsilon: 0.03
# Ep: 709| Reward: 160 | Epsilon: 0.03
# Ep: 710| Reward: 74 | Epsilon: 0.03
# Ep: 711| Reward: 200 | Epsilon: 0.03
# Ep: 712| Reward: 128 | Epsilon: 0.03
# Ep: 713| Reward: 131 | Epsilon: 0.03
# Ep: 714| Reward: 116 | Epsilon: 0.03
# Ep: 715| Reward: 146 | Epsilon: 0.03
# Ep: 716| Reward: 200 | Epsilon: 0.03
# Ep: 717| Reward: 122 | Epsilon: 0.03
# Ep: 718| Reward: 171 | Epsilon: 0.03
# Ep: 719| Reward: 177 | Epsilon: 0.03
# Ep: 720| Reward: 102 | Epsilon: 0.03
# Ep: 721| Reward: 93 | Epsilon: 0.03
# Ep: 722| Reward: 144 | Epsilon: 0.03
# Ep: 723| Reward: 137 | Epsilon: 0.03
# Ep: 724| Reward: 74 | Epsilon: 0.03
# Ep: 725| Reward: 174 | Epsilon: 0.03
# Ep: 726| Reward: 124 | Epsilon: 0.03
# Ep: 727| Reward: 200 | Epsilon: 0.03
# Ep: 728| Reward: 118 | Epsilon: 0.03
# Ep: 729| Reward: 200 | Epsilon: 0.03
# Ep: 730| Reward: 142 | Epsilon: 0.03
# Ep: 731| Reward: 200 | Epsilon: 0.03
# Ep: 732| Reward: 125 | Epsilon: 0.03
# Ep: 733| Reward: 90 | Epsilon: 0.03
# Ep: 734| Reward: 107 | Epsilon: 0.03
# Ep: 735| Reward: 200 | Epsilon: 0.02
# Ep: 736| Reward: 200 | Epsilon: 0.02
# Ep: 737| Reward: 184 | Epsilon: 0.02
# Ep: 738| Reward: 114 | Epsilon: 0.02
# Ep: 739| Reward: 152 | Epsilon: 0.02
# Ep: 740| Reward: 200 | Epsilon: 0.02
# Ep: 741| Reward: 108 | Epsilon: 0.02
# Ep: 742| Reward: 200 | Epsilon: 0.02
# Ep: 743| Reward: 185 | Epsilon: 0.02
# Ep: 744| Reward: 137 | Epsilon: 0.02
# Ep: 745| Reward: 136 | Epsilon: 0.02
# Ep: 746| Reward: 104 | Epsilon: 0.02
# Ep: 747| Reward: 117 | Epsilon: 0.02
# Ep: 748| Reward: 200 | Epsilon: 0.02
# Ep: 749| Reward: 141 | Epsilon: 0.02
# Ep: 750| Reward: 101 | Epsilon: 0.02
# Ep: 751| Reward: 141 | Epsilon: 0.02
# Ep: 752| Reward: 23 | Epsilon: 0.02
# Ep: 753| Reward: 88 | Epsilon: 0.02
# Ep: 754| Reward: 113 | Epsilon: 0.02
# Ep: 755| Reward: 200 | Epsilon: 0.02
# Ep: 756| Reward: 200 | Epsilon: 0.02
# Ep: 757| Reward: 200 | Epsilon: 0.02
# Ep: 758| Reward: 98 | Epsilon: 0.02
# Ep: 759| Reward: 181 | Epsilon: 0.02
# Ep: 760| Reward: 105 | Epsilon: 0.02
# Ep: 761| Reward: 200 | Epsilon: 0.02
# Ep: 762| Reward: 134 | Epsilon: 0.02
# Ep: 763| Reward: 143 | Epsilon: 0.02
# Ep: 764| Reward: 155 | Epsilon: 0.02
# Ep: 765| Reward: 12 | Epsilon: 0.02
# Ep: 766| Reward: 20 | Epsilon: 0.02
# Ep: 767| Reward: 144 | Epsilon: 0.02
# Ep: 768| Reward: 62 | Epsilon: 0.02
# Ep: 769| Reward: 55 | Epsilon: 0.02
# Ep: 770| Reward: 200 | Epsilon: 0.02
# Ep: 771| Reward: 200 | Epsilon: 0.02
# Ep: 772| Reward: 44 | Epsilon: 0.02
# Ep: 773| Reward: 135 | Epsilon: 0.02
# Ep: 774| Reward: 116 | Epsilon: 0.02
# Ep: 775| Reward: 100 | Epsilon: 0.02
# Ep: 776| Reward: 104 | Epsilon: 0.02
# Ep: 777| Reward: 121 | Epsilon: 0.02
# Ep: 778| Reward: 184 | Epsilon: 0.02
# Ep: 779| Reward: 179 | Epsilon: 0.02
# Ep: 780| Reward: 105 | Epsilon: 0.02
# Ep: 781| Reward: 101 | Epsilon: 0.02
# Ep: 782| Reward: 157 | Epsilon: 0.02
# Ep: 783| Reward: 126 | Epsilon: 0.02
# Ep: 784| Reward: 103 | Epsilon: 0.02
# Ep: 785| Reward: 109 | Epsilon: 0.02
# Ep: 786| Reward: 181 | Epsilon: 0.02
# Ep: 787| Reward: 192 | Epsilon: 0.02
# Ep: 788| Reward: 88 | Epsilon: 0.02
# Ep: 789| Reward: 115 | Epsilon: 0.02
# Ep: 790| Reward: 200 | Epsilon: 0.02
# Ep: 791| Reward: 164 | Epsilon: 0.02
# Ep: 792| Reward: 102 | Epsilon: 0.02
# Ep: 793| Reward: 121 | Epsilon: 0.02
# Ep: 794| Reward: 76 | Epsilon: 0.02
# Ep: 795| Reward: 174 | Epsilon: 0.02
# Ep: 796| Reward: 200 | Epsilon: 0.02
# Ep: 797| Reward: 158 | Epsilon: 0.02
# Ep: 798| Reward: 200 | Epsilon: 0.02
# Ep: 799| Reward: 200 | Epsilon: 0.02
# Ep: 800| Reward: 115 | Epsilon: 0.02
# Ep: 801| Reward: 139 | Epsilon: 0.02
# Ep: 802| Reward: 104 | Epsilon: 0.02
# Ep: 803| Reward: 184 | Epsilon: 0.02
# Ep: 804| Reward: 198 | Epsilon: 0.02
# Ep: 805| Reward: 27 | Epsilon: 0.02
# Ep: 806| Reward: 148 | Epsilon: 0.02
# Ep: 807| Reward: 155 | Epsilon: 0.02
# Ep: 808| Reward: 102 | Epsilon: 0.02
# Ep: 809| Reward: 89 | Epsilon: 0.02
# Ep: 810| Reward: 200 | Epsilon: 0.02
# Ep: 811| Reward: 200 | Epsilon: 0.02
# Ep: 812| Reward: 131 | Epsilon: 0.02
# Ep: 813| Reward: 200 | Epsilon: 0.02
# Ep: 814| Reward: 168 | Epsilon: 0.02
# Ep: 815| Reward: 60 | Epsilon: 0.02
# Ep: 816| Reward: 104 | Epsilon: 0.02
# Ep: 817| Reward: 133 | Epsilon: 0.02
# Ep: 818| Reward: 74 | Epsilon: 0.02
# Ep: 819| Reward: 200 | Epsilon: 0.02
# Ep: 820| Reward: 112 | Epsilon: 0.02
# Ep: 821| Reward: 81 | Epsilon: 0.02
# Ep: 822| Reward: 148 | Epsilon: 0.02
# Ep: 823| Reward: 200 | Epsilon: 0.02
# Ep: 824| Reward: 71 | Epsilon: 0.02
# Ep: 825| Reward: 164 | Epsilon: 0.02
# Ep: 826| Reward: 200 | Epsilon: 0.02
# Ep: 827| Reward: 100 | Epsilon: 0.02
# Ep: 828| Reward: 186 | Epsilon: 0.02
# Ep: 829| Reward: 147 | Epsilon: 0.02
# Ep: 830| Reward: 108 | Epsilon: 0.02
# Ep: 831| Reward: 125 | Epsilon: 0.02
# Ep: 832| Reward: 138 | Epsilon: 0.02
# Ep: 833| Reward: 133 | Epsilon: 0.02
# Ep: 834| Reward: 89 | Epsilon: 0.02
# Ep: 835| Reward: 166 | Epsilon: 0.02
# Ep: 836| Reward: 166 | Epsilon: 0.02
# Ep: 837| Reward: 200 | Epsilon: 0.01
# Ep: 838| Reward: 128 | Epsilon: 0.01
# Ep: 839| Reward: 27 | Epsilon: 0.01
# Ep: 840| Reward: 38 | Epsilon: 0.01
# Ep: 841| Reward: 110 | Epsilon: 0.01
# Ep: 842| Reward: 119 | Epsilon: 0.01
# Ep: 843| Reward: 200 | Epsilon: 0.01
# Ep: 844| Reward: 92 | Epsilon: 0.01
# Ep: 845| Reward: 181 | Epsilon: 0.01
# Ep: 846| Reward: 142 | Epsilon: 0.01
# Ep: 847| Reward: 200 | Epsilon: 0.01
# Ep: 848| Reward: 200 | Epsilon: 0.01
# Ep: 849| Reward: 200 | Epsilon: 0.01
# Ep: 850| Reward: 168 | Epsilon: 0.01
# Ep: 851| Reward: 86 | Epsilon: 0.01
# Ep: 852| Reward: 170 | Epsilon: 0.01
# Ep: 853| Reward: 71 | Epsilon: 0.01
# Ep: 854| Reward: 170 | Epsilon: 0.01
# Ep: 855| Reward: 112 | Epsilon: 0.01
# Ep: 856| Reward: 59 | Epsilon: 0.01
# Ep: 857| Reward: 23 | Epsilon: 0.01
# Ep: 858| Reward: 144 | Epsilon: 0.01
# Ep: 859| Reward: 133 | Epsilon: 0.01
# Ep: 860| Reward: 110 | Epsilon: 0.01
# Ep: 861| Reward: 200 | Epsilon: 0.01
# Ep: 862| Reward: 105 | Epsilon: 0.01
# Ep: 863| Reward: 114 | Epsilon: 0.01
# Ep: 864| Reward: 40 | Epsilon: 0.01
# Ep: 865| Reward: 200 | Epsilon: 0.01
# Ep: 866| Reward: 121 | Epsilon: 0.01
# Ep: 867| Reward: 109 | Epsilon: 0.01
# Ep: 868| Reward: 176 | Epsilon: 0.01
# Ep: 869| Reward: 187 | Epsilon: 0.01
# Ep: 870| Reward: 200 | Epsilon: 0.01
# Ep: 871| Reward: 29 | Epsilon: 0.01
# Ep: 872| Reward: 36 | Epsilon: 0.01
# Ep: 873| Reward: 200 | Epsilon: 0.01
# Ep: 874| Reward: 99 | Epsilon: 0.01
# Ep: 875| Reward: 200 | Epsilon: 0.01
# Ep: 876| Reward: 108 | Epsilon: 0.01
# Ep: 877| Reward: 90 | Epsilon: 0.01
# Ep: 878| Reward: 29 | Epsilon: 0.01
# Ep: 879| Reward: 45 | Epsilon: 0.01
# Ep: 880| Reward: 15 | Epsilon: 0.01
# Ep: 881| Reward: 189 | Epsilon: 0.01
# Ep: 882| Reward: 22 | Epsilon: 0.01
# Ep: 883| Reward: 136 | Epsilon: 0.01
# Ep: 884| Reward: 165 | Epsilon: 0.01
# Ep: 885| Reward: 73 | Epsilon: 0.01
# Ep: 886| Reward: 39 | Epsilon: 0.01
# Ep: 887| Reward: 114 | Epsilon: 0.01
# Ep: 888| Reward: 92 | Epsilon: 0.01
# Ep: 889| Reward: 64 | Epsilon: 0.01
# Ep: 890| Reward: 86 | Epsilon: 0.01
# Ep: 891| Reward: 31 | Epsilon: 0.01
# Ep: 892| Reward: 36 | Epsilon: 0.01
# Ep: 893| Reward: 97 | Epsilon: 0.01
# Ep: 894| Reward: 171 | Epsilon: 0.01
# Ep: 895| Reward: 21 | Epsilon: 0.01
# Ep: 896| Reward: 157 | Epsilon: 0.01
# Ep: 897| Reward: 120 | Epsilon: 0.01
# Ep: 898| Reward: 99 | Epsilon: 0.01
# Ep: 899| Reward: 121 | Epsilon: 0.01
# Ep: 900| Reward: 98 | Epsilon: 0.01
# Ep: 901| Reward: 111 | Epsilon: 0.01
# Ep: 902| Reward: 108 | Epsilon: 0.01
# Ep: 903| Reward: 125 | Epsilon: 0.01
# Ep: 904| Reward: 146 | Epsilon: 0.01
# Ep: 905| Reward: 200 | Epsilon: 0.01
# Ep: 906| Reward: 123 | Epsilon: 0.01
# Ep: 907| Reward: 200 | Epsilon: 0.01
# Ep: 908| Reward: 84 | Epsilon: 0.01
# Ep: 909| Reward: 106 | Epsilon: 0.01
# Ep: 910| Reward: 108 | Epsilon: 0.01
# Ep: 911| Reward: 95 | Epsilon: 0.01
# Ep: 912| Reward: 83 | Epsilon: 0.01
# Ep: 913| Reward: 47 | Epsilon: 0.01
# Ep: 914| Reward: 102 | Epsilon: 0.01
# Ep: 915| Reward: 200 | Epsilon: 0.01
# Ep: 916| Reward: 127 | Epsilon: 0.01
# Ep: 917| Reward: 117 | Epsilon: 0.01
# Ep: 918| Reward: 99 | Epsilon: 0.01
# Ep: 919| Reward: 118 | Epsilon: 0.01
# Ep: 920| Reward: 200 | Epsilon: 0.01
# Ep: 921| Reward: 54 | Epsilon: 0.01
# Ep: 922| Reward: 122 | Epsilon: 0.01
# Ep: 923| Reward: 158 | Epsilon: 0.01
# Ep: 924| Reward: 200 | Epsilon: 0.01
# Ep: 925| Reward: 126 | Epsilon: 0.01
# Ep: 926| Reward: 88 | Epsilon: 0.01
# Ep: 927| Reward: 146 | Epsilon: 0.01
# Ep: 928| Reward: 118 | Epsilon: 0.01
# Ep: 929| Reward: 97 | Epsilon: 0.01
# Ep: 930| Reward: 200 | Epsilon: 0.01
# Ep: 931| Reward: 96 | Epsilon: 0.01
# Ep: 932| Reward: 140 | Epsilon: 0.01
# Ep: 933| Reward: 108 | Epsilon: 0.01
# Ep: 934| Reward: 22 | Epsilon: 0.01
# Ep: 935| Reward: 158 | Epsilon: 0.01
# Ep: 936| Reward: 38 | Epsilon: 0.01
# Ep: 937| Reward: 200 | Epsilon: 0.01
# Ep: 938| Reward: 94 | Epsilon: 0.01
# Ep: 939| Reward: 155 | Epsilon: 0.01
# Ep: 940| Reward: 153 | Epsilon: 0.01
# Ep: 941| Reward: 200 | Epsilon: 0.01
# Ep: 942| Reward: 141 | Epsilon: 0.01
# Ep: 943| Reward: 128 | Epsilon: 0.01
# Ep: 944| Reward: 200 | Epsilon: 0.01
# Ep: 945| Reward: 56 | Epsilon: 0.01
# Ep: 946| Reward: 101 | Epsilon: 0.01
# Ep: 947| Reward: 92 | Epsilon: 0.01
# Ep: 948| Reward: 84 | Epsilon: 0.01
# Ep: 949| Reward: 102 | Epsilon: 0.01
# Ep: 950| Reward: 195 | Epsilon: 0.01
# Ep: 951| Reward: 143 | Epsilon: 0.01
# Ep: 952| Reward: 200 | Epsilon: 0.01
# Ep: 953| Reward: 151 | Epsilon: 0.01
# Ep: 954| Reward: 118 | Epsilon: 0.01
# Ep: 955| Reward: 177 | Epsilon: 0.01
# Ep: 956| Reward: 100 | Epsilon: 0.01
# Ep: 957| Reward: 100 | Epsilon: 0.01
# Ep: 958| Reward: 146 | Epsilon: 0.01
# Ep: 959| Reward: 116 | Epsilon: 0.01
# Ep: 960| Reward: 85 | Epsilon: 0.01
# Ep: 961| Reward: 84 | Epsilon: 0.01
# Ep: 962| Reward: 18 | Epsilon: 0.01
# Ep: 963| Reward: 21 | Epsilon: 0.01
# Ep: 964| Reward: 17 | Epsilon: 0.01
# Ep: 965| Reward: 105 | Epsilon: 0.01
# Ep: 966| Reward: 122 | Epsilon: 0.01
# Ep: 967| Reward: 97 | Epsilon: 0.01
# Ep: 968| Reward: 200 | Epsilon: 0.01
# Ep: 969| Reward: 20 | Epsilon: 0.01
# Ep: 970| Reward: 22 | Epsilon: 0.01
# Ep: 971| Reward: 126 | Epsilon: 0.01
# Ep: 972| Reward: 200 | Epsilon: 0.01
# Ep: 973| Reward: 166 | Epsilon: 0.01
# Ep: 974| Reward: 115 | Epsilon: 0.01
# Ep: 975| Reward: 110 | Epsilon: 0.01
# Ep: 976| Reward: 96 | Epsilon: 0.01
# Ep: 977| Reward: 74 | Epsilon: 0.01
# Ep: 978| Reward: 111 | Epsilon: 0.01
# Ep: 979| Reward: 142 | Epsilon: 0.01
# Ep: 980| Reward: 118 | Epsilon: 0.01
# Ep: 981| Reward: 144 | Epsilon: 0.01
# Ep: 982| Reward: 154 | Epsilon: 0.01
# Ep: 983| Reward: 200 | Epsilon: 0.01
# Ep: 984| Reward: 148 | Epsilon: 0.01
# Ep: 985| Reward: 200 | Epsilon: 0.01
# Ep: 986| Reward: 128 | Epsilon: 0.01
# Ep: 987| Reward: 152 | Epsilon: 0.01
# Ep: 988| Reward: 140 | Epsilon: 0.01
# Ep: 989| Reward: 142 | Epsilon: 0.01
# Ep: 990| Reward: 153 | Epsilon: 0.01
# Ep: 991| Reward: 184 | Epsilon: 0.01
# Ep: 992| Reward: 108 | Epsilon: 0.01
# Ep: 993| Reward: 46 | Epsilon: 0.01
# Ep: 994| Reward: 114 | Epsilon: 0.01
# Ep: 995| Reward: 150 | Epsilon: 0.01
# Ep: 996| Reward: 127 | Epsilon: 0.01
# Ep: 997| Reward: 165 | Epsilon: 0.01
# Ep: 998| Reward: 198 | Epsilon: 0.01
# Ep: 999| Reward: 167 | Epsilon: 0.01

# %% [markdown]
# # Results Analysis

# %%
def get_stats(steps, size=250):
    '''
    Returns the running average of episode length every *size* steps.
    
    Inputs:
        size (INT)
            The number of steps to calculating the running average over
            Default: 250
    '''
    sections = [i*size+(size//2) for i in range(len(steps)//size)]
    running_avg_ts = [np.mean(steps[s-(size//2):s+(size//2)]).round(2) for s in sections]

    return sections, running_avg_ts


SIZE = 25
q_learn_sections, q_learn_mean_ts = get_stats(q_learning_trainer.steps, size=SIZE)
DQN_sections, DQN_mean_ts = get_stats(DQN_trainer.steps, size=SIZE)

# %%
plt.figure(figsize=(20,7), dpi=100)
plt.subplot(1,2,1)
plt.title(f'Q-Learning Return over 1000 episodes (Training time = {round(q_learn_time,2)}s)', size=20)
plt.xlabel('Episode', size=15)
plt.ylabel('Time-steps / Reward', size=15)
plt.plot(q_learning_trainer.steps, alpha=0.95)
plt.plot(q_learn_sections, q_learn_mean_ts, color='coral', label='Running Average')
plt.legend()

plt.subplot(1,2,2)
plt.title(f'DQN Return over 1000 episodes (Training time = {round(DQN_time,2)}s)', size=20)
plt.xlabel('Episode', size=15)
plt.ylabel('Return', size=15)
plt.plot(DQN_trainer.steps, alpha=0.95)
plt.plot(DQN_sections, DQN_mean_ts, color='coral', label='Running Average')
plt.legend()
